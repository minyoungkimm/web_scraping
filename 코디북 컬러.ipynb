# %%
import numpy as np

import pickle
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
color=pd.read_csv('c:/Temp/크롤링/codibook/color.csv')
color
# Out:
#         id  color
# 0        1      1
# 1       10      9
# 2      100      9
# 3     1000      1
# 4     1001      1
# ...    ...    ...
# 2011   995      7
# 2012   996      3
# 2013   997      7
# 2014   998      7
# 2015   999      9
#
# [2016 rows x 2 columns]

# %%
color_mapping = { 0: '갈색' , 1 : '검정색',2: '노란색',3: '보라색', 4:'분홍색', 
                 5: '빨간색' ,6: '초록색' ,7: '파란색' ,8: '회색' ,9: '흰색'}

# %%
color['id']=color['id'].astype(int)
color.sort_values(by='id')
# Out:
#         id  color
# 0        1      1
# 1111     2      4
# 1239     3      5
# 1350     4      9
# 1461     5      8
# ...    ...    ...
# 1127  2012      1
# 1128  2013      1
# 1129  2014      9
# 1130  2015      9
# 1131  2016      1
#
# [2016 rows x 2 columns]

# %%
codibook=pd.read_csv('c:/Temp/크롤링/codibook.csv')
codibook
# Out:
#                                                    img  \
# 0    https://i0.codibook.net/files/thumb/medium/197...
# 1    https://i0.codibook.net/files/thumb/medium/197...
# 2    https://i0.codibook.net/files/thumb/medium/197...
# 3    https://i0.codibook.net/files/thumb/medium/197...
# 4    https://i0.codibook.net/files/thumb/medium/197...
# ..                                                 ...
# 667  https://i0.codibook.net/files/thumb/medium/197...
# 668  https://i0.codibook.net/files/thumb/medium/197...
# 669  https://i0.codibook.net/files/thumb/medium/197...
# 670  https://i0.codibook.net/files/thumb/medium/197...
# 671  https://i0.codibook.net/files/thumb/medium/197...
#
#                                               each_img  like
# 0    ['https://i0.codibook.net/files/thumb/small/19...     3
# 1    ['https://i0.codibook.net/files/thumb/small/19...    18
# 2    ['https://i0.codibook.net/files/thumb/small/19...    16
# ...

# %%
codibook['color_mix']=color_list
codibook
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-b5c2cc3e3c85> in <module>
# ----> 1 codibook['color_mix']=color_list
#       2 codibook
#
# NameError: name 'color_list' is not defined

# %%
id_list=[]
for x in range(len(codibook['color_mix'])):
    if codibook['color_mix'][x]==['검정색','흰색'] or codibook['color_mix'][x]==['흰색','검정색'] \
    or codibook['color_mix'][x]==['검정색','파란색','흰색'] or codibook['color_mix'][x]==['검정색','흰색','파란색'] or codibook['color_mix'][x]==['흰색','검정색','파란색'] or codibook['color_mix'][x]==['흰색','파란색','검정색'] or codibook['color_mix'][x]==['파란색','검정색','흰색'] or codibook['color_mix'][x]==['파란색','흰색','검정색']\
    or codibook['color_mix'][x]==['검정색','분홍색','흰색'] or codibook['color_mix'][x]==['검정색','흰색','분홍색'] or codibook['color_mix'][x]==['흰색','검정색','분홍색'] or codibook['color_mix'][x]==['흰색','분홍색','검정색'] or codibook['color_mix'][x]==['분홍색','검정색','흰색'] or codibook['color_mix'][x]==['분홍색','흰색','검정색']\
    or codibook['color_mix'][x]==['검정색','노란색','흰색'] or codibook['color_mix'][x]==['검정색','흰색','노란색'] or codibook['color_mix'][x]==['흰색','검정색','노란색'] or codibook['color_mix'][x]==['흰색','노란색','검정색'] or codibook['color_mix'][x]==['노란색','검정색','흰색'] or codibook['color_mix'][x]==['노란색','흰색','검정색']\
    or codibook['color_mix'][x]==['검정색','갈색','흰색'] or codibook['color_mix'][x]==['검정색','흰색','갈색'] or codibook['color_mix'][x]==['흰색','검정색','갈색'] or codibook['color_mix'][x]==['흰색','갈색','검정색'] or codibook['color_mix'][x]==['갈색','검정색','흰색'] or codibook['color_mix'][x]==['갈색','흰색','검정색']\
    or codibook['color_mix'][x]==['파란색','흰색'] or codibook['color_mix'][x]==['흰색','파란색'] \
    or codibook['color_mix'][x]==['검정색','파란색'] or codibook['color_mix'][x]==['파란색','검정색'] \
    or codibook['color_mix'][x]==['흰색']\
    or codibook['color_mix'][x]==['검정색']\
    :
        id_list.append(x)
len(id_list)
# Out:
# 458

# %%
codibook_top=codibook[codibook.reset_index().index.isin(id_list)]

# %%
for x in codibook_top['color_mix'].index:
    codibook_top['color_mix'][x].sort()
    
codibook_top
# Out:
#                                                    img  \
# 2    https://i0.codibook.net/files/thumb/medium/197...
# 3    https://i0.codibook.net/files/thumb/medium/197...
# 4    https://i0.codibook.net/files/thumb/medium/197...
# 9    https://i0.codibook.net/files/thumb/medium/197...
# 10   https://i0.codibook.net/files/thumb/medium/197...
# ..                                                 ...
# 665  https://i0.codibook.net/files/thumb/medium/197...
# 666  https://i0.codibook.net/files/thumb/medium/197...
# 667  https://i0.codibook.net/files/thumb/medium/197...
# 668  https://i0.codibook.net/files/thumb/medium/197...
# 671  https://i0.codibook.net/files/thumb/medium/197...
#
#                                               each_img  like       color_mix
# 2    ['https://i0.codibook.net/files/thumb/small/19...    16  [검정색, 파란색, 흰색]
# 3    ['https://i0.codibook.net/files/thumb/small/19...    20            [흰색]
# ...

# %%
codibook_top['color_mix'][2]
# Out:
# list

# %%
test=codibook_top[['img','like','color_mix']].sort_values(by='color_mix')
test
# codibook_top.sort_values(by='color_mix')
# Out:
#                                                    img  like      color_mix
# 308  https://i0.codibook.net/files/thumb/medium/197...    37  [갈색, 검정색, 흰색]
# 260  https://i0.codibook.net/files/thumb/medium/197...   293  [갈색, 검정색, 흰색]
# 533  https://i0.codibook.net/files/thumb/medium/197...    43  [갈색, 검정색, 흰색]
# 519  https://i0.codibook.net/files/thumb/medium/197...    46  [갈색, 검정색, 흰색]
# 251  https://i0.codibook.net/files/thumb/medium/197...    63  [갈색, 검정색, 흰색]
# ..                                                 ...   ...            ...
# 286  https://i0.codibook.net/files/thumb/medium/197...    68           [흰색]
# 230  https://i0.codibook.net/files/thumb/medium/197...    66           [흰색]
# 384  https://i0.codibook.net/files/thumb/medium/197...   101           [흰색]
# 233  https://i0.codibook.net/files/thumb/medium/197...    91           [흰색]
# 210  https://i0.codibook.net/files/thumb/medium/197...   293           [흰색]
#
# [458 rows x 3 columns]

# %%
test['color_mix']=test['color_mix'].astype(str)

# %%
# test.info()
ranking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   color_mix  9 non-null      object
#  1   rank       9 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 272.0+ bytes

# %%
m_list=list(test['color_mix'].unique())
rank=[9,7,5,8,6,2,1,3,4]
ranking=pd.DataFrame({'color_mix':m_list,'rank':rank})
ranking
# Out:
#               color_mix  rank
# 0   ['갈색', '검정색', '흰색']     9
# 1               ['검정색']     7
# 2  ['검정색', '노란색', '흰색']     5
# 3  ['검정색', '분홍색', '흰색']     8
# 4        ['검정색', '파란색']     6
# 5  ['검정색', '파란색', '흰색']     2
# 6         ['검정색', '흰색']     1
# 7         ['파란색', '흰색']     3
# 8                ['흰색']     4

# %%
test_merge=pd.merge(test,ranking,how='left',on='color_mix')
test_merge
# Out:
#                                                    img  like  \
# 0    https://i0.codibook.net/files/thumb/medium/197...    37
# 1    https://i0.codibook.net/files/thumb/medium/197...   293
# 2    https://i0.codibook.net/files/thumb/medium/197...    43
# 3    https://i0.codibook.net/files/thumb/medium/197...    46
# 4    https://i0.codibook.net/files/thumb/medium/197...    63
# ..                                                 ...   ...
# 453  https://i0.codibook.net/files/thumb/medium/197...    68
# 454  https://i0.codibook.net/files/thumb/medium/197...    66
# 455  https://i0.codibook.net/files/thumb/medium/197...   101
# 456  https://i0.codibook.net/files/thumb/medium/197...    91
# 457  https://i0.codibook.net/files/thumb/medium/197...   293
#
#                color_mix  rank
# 0    ['갈색', '검정색', '흰색']     9
# 1    ['갈색', '검정색', '흰색']     9
# 2    ['갈색', '검정색', '흰색']     9
# 3    ['갈색', '검정색', '흰색']     9
# 4    ['갈색', '검정색', '흰색']     9
# ..                   ...   ...
# ...

# %%
test.to_csv('c:/Temp/크롤링/final.csv',encoding='utf-8-sig',index=False)
test=pd.read_csv('c:/Temp/크롤링/final.csv')
test

# %%
# outfit_table=test_merge.values.tolist()
# len(outfit_table)
# Out:
# 458

# %%
codibook_top['img'][617]
# Out:
# 'https://i0.codibook.net/files/thumb/medium/197804257571/15e1fc9de8e6ca37/2109535378.jpg'

# %%
outfit_table[0][1]
# Out:
# 37

# %%
# Out:
# 458

# %%
# outfit_table

# %%
import json
import boto3
from boto3.dynamodb.conditions import Key, Attr

############## DB 정보 ############## 
dynamodb = boto3.resource('dynamodb', region_name='us-east-2')
table = dynamodb.Table('Recommendations')

index=1
for outfit in outfit_table:
    outfit_id = index
    url = outfit[0]
    color_list = outfit[2]
    likes = outfit[1]
    rank = outfit[3]
    
    resp = table.put_item(Item={"outfit_id":outfit_id, "url":url, "color_list":color_list, "likes":likes, "rank":rank})

    index += 1
    print(resp)

return ("Success!")

# %%
# codibook['each_img'][0].replace('[','')
# codibook['each_img'][0].replace(']','')
# codibook['each_img'][0].replace("''",'')
# Out:
# "['https://i0.codibook.net/files/thumb/small/1977120230317/16277612461d24/1180769939.png', 'https://i0.codibook.net/files/thumb/small/1978050535205/eb863e61814d6edc/57576467.png', 'https://i0.codibook.net/files/thumb/small/197805215565/f4160b0409ea6008/1112250114.png']"

# %%
x_list=[]
for x in codibook['each_img']:
    x = x.replace('[','')
    x = x.replace(']','')
    x_list.append(x)
    
# x_list

# %%
codibook['x_list']=x_list
y_list=[]
for x in codibook['x_list']:
    y=x.split(',')
    for z in y:
        z= z.replace("'","")
        x= z.replace(" ","")
        y_list.append(z)

# %%
from itertools import chain, repeat

img_rep=list(chain.from_iterable((repeat(i, 3) for i in codibook['img'])))
len(img_rep)
like_rep=list(chain.from_iterable((repeat(i, 3) for i in codibook['like'])))

# %%
len(img_rep)
# Out:
# 2016

# %%
# i_list=[]
# for i in codibook['each_img']:
#     i = i.replace(" ","")
#     i_list.append(i)

# len(i_list)
# Out:
# 672

# %%
codibook=pd.DataFrame({'codi_img':img_rep,'each_img':y_list,'like':like_rep})
codibook
# Out:
#                                                codi_img  \
# 0     https://i0.codibook.net/files/thumb/medium/197...
# 1     https://i0.codibook.net/files/thumb/medium/197...
# 2     https://i0.codibook.net/files/thumb/medium/197...
# 3     https://i0.codibook.net/files/thumb/medium/197...
# 4     https://i0.codibook.net/files/thumb/medium/197...
# ...                                                 ...
# 2011  https://i0.codibook.net/files/thumb/medium/197...
# 2012  https://i0.codibook.net/files/thumb/medium/197...
# 2013  https://i0.codibook.net/files/thumb/medium/197...
# 2014  https://i0.codibook.net/files/thumb/medium/197...
# 2015  https://i0.codibook.net/files/thumb/medium/197...
#
#                                                each_img  like
# 0     https://i0.codibook.net/files/thumb/small/1977...     3
# 1      https://i0.codibook.net/files/thumb/small/197...     3
# 2      https://i0.codibook.net/files/thumb/small/197...     3
# ...

# %%
i_list=[]
for i in codibook['each_img']:
    i = i.replace(' ','')
    i_list.append(i)

codibook['each_img']=i_list

# %%
codibook
# Out:
#                                                codi_img  \
# 0     https://i0.codibook.net/files/thumb/medium/197...
# 1     https://i0.codibook.net/files/thumb/medium/197...
# 2     https://i0.codibook.net/files/thumb/medium/197...
# 3     https://i0.codibook.net/files/thumb/medium/197...
# 4     https://i0.codibook.net/files/thumb/medium/197...
# ...                                                 ...
# 2011  https://i0.codibook.net/files/thumb/medium/197...
# 2012  https://i0.codibook.net/files/thumb/medium/197...
# 2013  https://i0.codibook.net/files/thumb/medium/197...
# 2014  https://i0.codibook.net/files/thumb/medium/197...
# 2015  https://i0.codibook.net/files/thumb/medium/197...
#
#                                                each_img  like
# 0     https://i0.codibook.net/files/thumb/small/1977...     3
# 1     https://i0.codibook.net/files/thumb/small/1978...     3
# 2     https://i0.codibook.net/files/thumb/small/1978...     3
# ...

# %% [markdown]
# ## color mapping

# %%
color=pd.read_csv('c:/Temp/크롤링/codibook/color.csv')
color
# Out:
#         id  color
# 0        1      1
# 1       10      9
# 2      100      9
# 3     1000      1
# 4     1001      1
# ...    ...    ...
# 2011   995      7
# 2012   996      3
# 2013   997      7
# 2014   998      7
# 2015   999      9
#
# [2016 rows x 2 columns]

# %%
color_mapping = { 0: '갈색' , 1 : '검정색',2: '노란색',3: '보라색', 4:'분홍색', 
                 5: '빨간색' ,6: '초록색' ,7: '파란색' ,8: '회색' ,9: '흰색'}

# %%
def mycovert_color(data,convert):
    return convert[data]

color['color']=color['color'].apply(mycovert_color,convert=color_mapping)
color
# Out:
#         id color
# 0        1   검정색
# 1       10    흰색
# 2      100    흰색
# 3     1000   검정색
# 4     1001   검정색
# ...    ...   ...
# 2011   995   파란색
# 2012   996   보라색
# 2013   997   파란색
# 2014   998   파란색
# 2015   999    흰색
#
# [2016 rows x 2 columns]

# %%
color['id']=color['id'].astype(int)
color.sort_values(by='id')
# Out:
#         id color
# 0        1   검정색
# 1111     2   분홍색
# 1239     3   빨간색
# 1350     4    흰색
# 1461     5    회색
# ...    ...   ...
# 1127  2012   검정색
# 1128  2013   검정색
# 1129  2014    흰색
# 1130  2015    흰색
# 1131  2016   검정색
#
# [2016 rows x 2 columns]

# %%
color.groupby('color').count()
# Out:
#         id
# color
# 갈색      49
# 검정색    644
# 노란색     98
# 보라색     31
# 분홍색     56
# 빨간색      2
# 초록색     19
# 파란색    246
# 회색      72
# 흰색     799

# %%
codibook['id']=codibook.reset_index().index.astype(int)+1
codibook
# Out:
#                                                codi_img  \
# 0     https://i0.codibook.net/files/thumb/medium/197...
# 1     https://i0.codibook.net/files/thumb/medium/197...
# 2     https://i0.codibook.net/files/thumb/medium/197...
# 3     https://i0.codibook.net/files/thumb/medium/197...
# 4     https://i0.codibook.net/files/thumb/medium/197...
# ...                                                 ...
# 2011  https://i0.codibook.net/files/thumb/medium/197...
# 2012  https://i0.codibook.net/files/thumb/medium/197...
# 2013  https://i0.codibook.net/files/thumb/medium/197...
# 2014  https://i0.codibook.net/files/thumb/medium/197...
# 2015  https://i0.codibook.net/files/thumb/medium/197...
#
#                                                each_img  like    id
# 0     https://i0.codibook.net/files/thumb/small/1977...     3     1
# 1     https://i0.codibook.net/files/thumb/small/1978...     3     2
# 2     https://i0.codibook.net/files/thumb/small/1978...     3     3
# ...

# %%
len(id_rep)
# Out:
# 2016

# %%
from itertools import chain, repeat

id_rep=list(chain.from_iterable((repeat(i, 3) for i in range(1,673))))
codibook['id_rep']=id_rep
codibook
# Out:
#                                                codi_img  \
# 0     https://i0.codibook.net/files/thumb/medium/197...
# 1     https://i0.codibook.net/files/thumb/medium/197...
# 2     https://i0.codibook.net/files/thumb/medium/197...
# 3     https://i0.codibook.net/files/thumb/medium/197...
# 4     https://i0.codibook.net/files/thumb/medium/197...
# ...                                                 ...
# 2011  https://i0.codibook.net/files/thumb/medium/197...
# 2012  https://i0.codibook.net/files/thumb/medium/197...
# 2013  https://i0.codibook.net/files/thumb/medium/197...
# 2014  https://i0.codibook.net/files/thumb/medium/197...
# 2015  https://i0.codibook.net/files/thumb/medium/197...
#
#                                                each_img  like    id  id_rep
# 0     https://i0.codibook.net/files/thumb/small/1977...     3     1       1
# 1     https://i0.codibook.net/files/thumb/small/1978...     3     2       1
# ...

# %%
codi=pd.merge(codibook,color,how='inner',on='id')
codi
# Out:
#                                                codi_img  \
# 0     https://i0.codibook.net/files/thumb/medium/197...
# 1     https://i0.codibook.net/files/thumb/medium/197...
# 2     https://i0.codibook.net/files/thumb/medium/197...
# 3     https://i0.codibook.net/files/thumb/medium/197...
# 4     https://i0.codibook.net/files/thumb/medium/197...
# ...                                                 ...
# 2011  https://i0.codibook.net/files/thumb/medium/197...
# 2012  https://i0.codibook.net/files/thumb/medium/197...
# 2013  https://i0.codibook.net/files/thumb/medium/197...
# 2014  https://i0.codibook.net/files/thumb/medium/197...
# 2015  https://i0.codibook.net/files/thumb/medium/197...
#
#                                                each_img  like    id  id_rep  \
# 0     https://i0.codibook.net/files/thumb/small/1977...     3     1       1
# 1     https://i0.codibook.net/files/thumb/small/1978...     3     2       1
# ...

# %% [markdown]
# - color리스트를 3개씩 묶어서 하나의 색 조합으로 만들기

# %%
color_list=list(codi['color'])

# %%
n = 3
result = [color_list[i * n:(i + 1) * n] for i in range((len(color_list) + n - 1) // n )] 
len(result)
# Out:
# 672

# %%
tt=pd.read_csv('c:/Temp/크롤링/codibook.csv')
tt
# Out:
#                                                    img  \
# 0    https://i0.codibook.net/files/thumb/medium/197...
# 1    https://i0.codibook.net/files/thumb/medium/197...
# 2    https://i0.codibook.net/files/thumb/medium/197...
# 3    https://i0.codibook.net/files/thumb/medium/197...
# 4    https://i0.codibook.net/files/thumb/medium/197...
# ..                                                 ...
# 667  https://i0.codibook.net/files/thumb/medium/197...
# 668  https://i0.codibook.net/files/thumb/medium/197...
# 669  https://i0.codibook.net/files/thumb/medium/197...
# 670  https://i0.codibook.net/files/thumb/medium/197...
# 671  https://i0.codibook.net/files/thumb/medium/197...
#
#                                               each_img  like
# 0    ['https://i0.codibook.net/files/thumb/small/19...     3
# 1    ['https://i0.codibook.net/files/thumb/small/19...    18
# 2    ['https://i0.codibook.net/files/thumb/small/19...    16
# ...

# %%
likes=list(tt['like'])
len(likes)
# n = 3
# likes = [likes[i * n:(i + 1) * n] for i in range((len(color_list) + n - 1) // n )]
# Out:
# 672

# %%
mix=pd.DataFrame({'color_mix':result,'like':likes})
idx=mix.reset_index().index+1
mix['id']=idx
mix=mix[['id','color_mix','like']]
mix
# Out:
#       id        color_mix  like
# 0      1  [검정색, 분홍색, 빨간색]     3
# 1      2    [흰색, 회색, 초록색]    18
# 2      3   [파란색, 검정색, 흰색]    16
# 3      4     [흰색, 흰색, 흰색]    20
# 4      5  [검정색, 검정색, 검정색]    17
# ..   ...              ...   ...
# 667  668   [분홍색, 검정색, 흰색]    75
# 668  669   [흰색, 검정색, 파란색]   129
# 669  670  [초록색, 노란색, 검정색]    45
# 670  671  [보라색, 검정색, 검정색]    40
# 671  672    [흰색, 흰색, 검정색]   196
#
# [672 rows x 3 columns]

# %%
## 컬러 중복 제거
color_list=[]
for x in mix['color_mix']:
    c_list=[]
    for y in x:
        if y not in c_list:
            if y != '':
                c_list.append(y)
                c_list.sort()
    color_list.append(c_list)

len(color_list)
# Out:
# 672

# %%
# yy=[]
# for x in color_list:
#     x.sort()
#     print(x)

# %%
mix['color_list']=color_list
mix
# Out:
#      index        color_mix  like       color_list
# 0        1  [검정색, 분홍색, 빨간색]     3  [검정색, 분홍색, 빨간색]
# 1        2    [흰색, 회색, 초록색]    18    [초록색, 회색, 흰색]
# 2        3   [파란색, 검정색, 흰색]    16   [검정색, 파란색, 흰색]
# 3        4     [흰색, 흰색, 흰색]    20             [흰색]
# 4        5  [검정색, 검정색, 검정색]    17            [검정색]
# ..     ...              ...   ...              ...
# 667    668   [분홍색, 검정색, 흰색]    75   [검정색, 분홍색, 흰색]
# 668    669   [흰색, 검정색, 파란색]   129   [검정색, 파란색, 흰색]
# 669    670  [초록색, 노란색, 검정색]    45  [검정색, 노란색, 초록색]
# 670    671  [보라색, 검정색, 검정색]    40       [검정색, 보라색]
# 671    672    [흰색, 흰색, 검정색]   196        [검정색, 흰색]
#
# [672 rows x 4 columns]

# %%
mix=mix.rename({'id':'index'},axis='columns')
mix
# Out:
#      index        color_mix  like       color_list
# 0        1  [검정색, 분홍색, 빨간색]     3  [검정색, 분홍색, 빨간색]
# 1        2    [흰색, 회색, 초록색]    18    [초록색, 회색, 흰색]
# 2        3   [파란색, 검정색, 흰색]    16   [검정색, 파란색, 흰색]
# 3        4     [흰색, 흰색, 흰색]    20             [흰색]
# 4        5  [검정색, 검정색, 검정색]    17            [검정색]
# ..     ...              ...   ...              ...
# 667    668   [분홍색, 검정색, 흰색]    75   [검정색, 분홍색, 흰색]
# 668    669   [흰색, 검정색, 파란색]   129   [검정색, 파란색, 흰색]
# 669    670  [초록색, 노란색, 검정색]    45  [검정색, 노란색, 초록색]
# 670    671  [보라색, 검정색, 검정색]    40       [검정색, 보라색]
# 671    672    [흰색, 흰색, 검정색]   196        [검정색, 흰색]
#
# [672 rows x 4 columns]

# %%
mix['color_list']=mix['color_list'].astype(str)
mix[['color_list','like']].groupby('color_list').max().sort_values(by='like',ascending=False).reset_index().head(10)
# Out:
#               color_list  like
# 0          ['검정색', '흰색']   602
# 1   ['검정색', '파란색', '흰색']   511
# 2  ['검정색', '노란색', '파란색']   432
# 3          ['파란색', '흰색']   365
# 4   ['검정색', '보라색', '흰색']   346
# 5          ['노란색', '흰색']   325
# 6         ['검정색', '노란색']   322
# 7   ['검정색', '노란색', '흰색']   308
# 8   ['갈색', '검정색', '파란색']   301
# 9                 ['흰색']   293

# %%
from pandas.plotting import register_matplotlib_converters
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
# font_path = 'Malgun Gothic.ttf'
# font_name = fm.FontProperties(fname=font_path, size=10).get_name()
# plt.rc('font', family=font_name, size=12)
# plt.rcParams["figure.figsize"] = (20, 10)
# register_matplotlib_converters()

mpl.font_manager._rebuild()
mpl.pyplot.rc('font', family='Malgun Gothic')
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# 아이디(id)와 색깔(color_mix) 추출
codi_color = mix[['index', 'color_list']]

# unnest color
color_unnest = np.dstack(
    (
        np.repeat(codi_color.index.values, list(map(len, codi_color.color_list))), 
        np.concatenate(codi_color.color_list.values)
    )
)

# unnested 데이터프레임 생성 : plylst_song_map
codi_color = pd.DataFrame(data = color_unnest[0], columns = codi_color.columns)
codi_color['index'] = codi_color['index'].astype(str)
codi_color['color_list'] = codi_color['color_list'].astype(str)

# unnest 객체 제거
del color_unnest

# %%
# 1. unnest 데이터프레임인 plylst_tag_map 테이블에서 태그 이름 정렬 후 list로 묶기
color_sort = codi_color.sort_values(by = ['index', 'color_list']).groupby('index').color_list.apply(list).reset_index(name = 'color_split')

# 2. 집계를 위해 1번 테이블에서 list 타입을 문자열 타입으로 변경
color_sort['color_split'] = color_sort['color_split'].astype(str)

# 3. 태그 리스트 별 매핑되는 플레이리스트 수 집계 테이블 생성 : tag_list_plylst_cnt
color_cnt = color_sort.groupby('color_split').index.nunique().reset_index(name = 'color_cnt')

# 4. 매핑 수 기준 상위 50개 필터링
# color_cnt = color_cnt.nlargest(10, 'color_cnt')

# 5. plotting
fig,axes=plt.figure(figsize = (11, 15))
color_cnt_plot = sns.barplot(y = 'color_split', x = 'color_cnt', data = color_cnt, color = 'Spectral')
color_cnt_plot.set_title('매핑된 컬러 리스트 상위 10개')
color_cnt_plot.set_xlabel('매핑된 게시물 수')
color_cnt_plot.set_ylabel('컬러 리스트')
plt.show()

# %%
# Out:
# Object `set_xlabel` not found.

# %%
# 1. unnest 데이터프레임인 plylst_tag_map 테이블에서 태그 이름 정렬 후 list로 묶기
color_sort = codi_color.sort_values(by = ['index', 'color_list']).groupby('index').color_list.apply(list).reset_index(name = 'color_split')

# 2. 집계를 위해 1번 테이블에서 list 타입을 문자열 타입으로 변경
color_sort['color_split'] = color_sort['color_split'].astype(str)

# 3. 태그 리스트 별 매핑되는 플레이리스트 수 집계 테이블 생성 : tag_list_plylst_cnt
color_cnt = color_sort.groupby('color_split').index.nunique().reset_index(name = 'color_cnt')

# 4. 매핑 수 기준 상위 50개 필터링
color_cnt = color_cnt.nlargest(10, 'color_cnt')

# 5. plotting
fig,ax = plt.subplots(figsize=(11,11))
plt.style.use('ggplot')
# fig.subplots_adjust(hspace=0.5)
# fig,ax = plt.figure(figsize = (11, 15))

sns.barplot(y = 'color_split', x = 'color_cnt', data = color_cnt,palette='Blues_r')
ax.set_title('매핑된 컬러 리스트 상위 10개',fontsize=18)
ax.set_xlabel('매핑된 게시물 수',fontsize=15)
# ax.set_ylabel('컬러 리스트',fontsize=15)
ax.tick_params(labelsize=13,length=0)
# plt.box(False)

plt.show()
fig.savefig("output.png")

# %%
# color_cnt['ratio']=round(color_cnt['color_cnt']/color_cnt.color_cnt.sum()*100,2)
# color_cnt=color_cnt.nlargest(10, 'color_cnt')
color_cnt
# Out:
#              color_split  color_cnt
# 37         ['검정색', '흰색']        167
# 33  ['검정색', '파란색', '흰색']         72
# 59         ['파란색', '흰색']         70
# 62                ['흰색']         34
# 18  ['검정색', '노란색', '흰색']         32
# 34        ['검정색', '파란색']         26
# 38               ['검정색']         23
# 27  ['검정색', '분홍색', '흰색']         21
# 35   ['검정색', '회색', '흰색']         16
# 45         ['노란색', '흰색']         15

# %%
fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

recipe = list(color_cnt['color_split'])

data = list(color_cnt['color_cnt'])

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.5), startangle=-40)

bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(recipe[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, **kw)

ax.set_title("Matplotlib bakery: A donut")

plt.show()

# %%
import matplotlib.pyplot as plt
# Pie chart
labels =  list(color_cnt['color_split'])
sizes = list(color_cnt['color_cnt'])
#colors
# colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
#explsion
# explode = (0.05,0.05,0.05,0.05)
 
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, pctdistance=0.85)
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-146-c73b0b2bea6e> in <module>
#       8 # explode = (0.05,0.05,0.05,0.05)
#       9
# ---> 10 plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, pctdistance=0.85,palette='dark2')
#      11 #draw circle
#      12 centre_circle = plt.Circle((0,0),0.70,fc='white')
#
# TypeError: pie() got an unexpected keyword argument 'palette'

# %%
import matplotlib.pyplot as plt

ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']
colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.show()
