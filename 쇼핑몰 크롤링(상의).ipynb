# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import re
import numpy as np
from bs4 import BeautifulSoup as bs
import pickle
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 8seconds 크롤링

# %%
browser = webdriver.Chrome('C:/Temp/chromedriver')
# browser.get("https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage=1&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=3%2C2%2C4&materNM=&cateViewOn=&cateNo=&fitPsbYn=N")

# %%
# import requests
# header = {'User-gent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.198 Safari/537.36'}
# html = requests.get('https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage=1&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=3%2C2%2C4&materNM=&cateViewOn=&cateNo=&fitPsbYn=N', headers = header).text
# html

# %% [markdown]
# ### 가디건

# %%
n=1
img_link=[]
like_list=[]

#검정가디건(195개)
while True:
    browser.get('https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=5&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1



#회색가디건(141개)
n=1
while True:
    browser.get('https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage='+ str(n) +'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=3%2C2%2C4&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
    
#노란색가디건(42개)-노란색/레몬색/겨자색
n=1
while True:
    browser.get('https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=E%2CG%2CF&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
#흰색가디건(187개)-흰색/아이보리
n=1
while True:
    browser.get('https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=0%2C1&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1    

    
    
#초록색가디건(103개)-카키/녹색/연두색/올리브/애플그린
n=1
while True:
    browser.get('https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=H%2CM%2CL%2CJ%2CK&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
    
    
#파란색가디건(84개)-하늘색/파란색/로열블루
n=1
while True:
    browser.get('https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=Q%2CP%2CN&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    

    
#보라색가디건(37개)-라벤다/연보라/보라/자주
n=1
while True:
    browser.get('https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=T%2CV%2CS%2CU&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
    
#빨간색가디건(15개)-빨간색
n=1
while True:
    browser.get('https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=6&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
#분홍색가디건(50개)-연분홍/분홍/코랄/진분홍
n=1
while True:
    browser.get('https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=Y%2CX%2C7%2CW&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
#갈색가디건(116개)-진한갈색/갈색/황토색
n=1
while True:
    browser.get('https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=D%2CB%2CC&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
print(len(img_link))
print(len(like_list))

#https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage=2&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=3%2C2%2C4&materNM=&cateViewOn=&cateNo=&fitPsbYn=N
# Out:
# 970
# 970

# %%
# 'https://www.ssfshop.com/Shirts/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage=1&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=5&materNM=&cateViewOn=&cateNo=&fitPsbYn=N'
# 'https://www.ssfshop.com/Shirts/list?dspCtgryNo=SFMA41A02A01&brandShopNo=&brndShopId=&currentPage=1&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=5&materNM=&cateViewOn=&cateNo=&fitPsbYn=N'
'https://www.ssfshop.com/Shirts/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage=1&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=3%2C2%2C4&materNM=&cateViewOn=&cateNo=&fitPsbYn=N'
'https://www.ssfshop.com/Shirts/list?dspCtgryNo=SFMA41A02A01&brandShopNo=&brndShopId=&currentPage=1&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=3%2C2&materNM=&cateViewOn=&cateNo=&fitPsbYn=N'

# %% [markdown]
# ### 셔츠

# %%
n=1
img_link=[]
like_list=[]

#검정셔츠(205개)
while True:
    browser.get('https://www.ssfshop.com/Shirts/list?dspCtgryNo=SFMA41A02A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=5&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1



#회색셔츠(96개)-회색/짙은회색/밝은회색
n=1
while True:
    browser.get('https://www.ssfshop.com/Shirts/list?dspCtgryNo=SFMA41A02A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=3%2C4%2C2&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
    
#노란색셔츠(66개)-노란색/레몬색/겨자색
n=1
while True:
    browser.get('https://www.ssfshop.com/Shirts/list?dspCtgryNo=SFMA41A02A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=E%2CF%2CG&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
#흰색셔츠(476개)-흰색/아이보리
n=1
while True:
    browser.get('https://www.ssfshop.com/Shirts/list?dspCtgryNo=SFMA41A02A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=1%2C0&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1    

    
    
#초록색셔츠(141개)-카키/녹색/연두색/올리브/애플그린
n=1
while True:
    browser.get('https://www.ssfshop.com/Shirts/list?dspCtgryNo=SFMA41A02A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=H%2CM%2CL%2CJ%2CK&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
    
    
#파란색셔츠(424개)-하늘색/파란색/로열블루/남색
n=1
while True:
    browser.get('https://www.ssfshop.com/Shirts/list?dspCtgryNo=SFMA41A02A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=Q%2CR%2CP%2CN&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    

    
#보라색셔츠(40개)-와인/라벤다/연보라/보라/자주
n=1
while True:
    browser.get('https://www.ssfshop.com/Shirts/list?dspCtgryNo=SFMA41A02A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=Z%2CS%2CT%2CV%2CU&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
    
#빨간색셔츠(37개)-빨간색
n=1
while True:
    browser.get('https://www.ssfshop.com/Shirts/list?dspCtgryNo=SFMA41A02A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=6&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
#분홍색셔츠(76개)-연분홍/분홍/코랄/진분홍
n=1
while True:
    browser.get('https://www.ssfshop.com/Shirts/list?dspCtgryNo=SFMA41A02A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=Y%2CX%2C7%2CW&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
#갈색셔츠(75개)-진한갈색/갈색/황토색
n=1
while True:
    browser.get('https://www.ssfshop.com/Shirts/list?dspCtgryNo=SFMA41A02A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=D%2CB%2CC&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
print(len(img_link))
print(len(like_list))

#https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage=2&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=3%2C2%2C4&materNM=&cateViewOn=&cateNo=&fitPsbYn=N
# Out:
# 1636
# 1636

# %% [markdown]
# ### 블라우스

# %%
n=1
img_link=[]
like_list=[]

#검정(329개)
while True:
    browser.get('https://www.ssfshop.com/Blouses/list?dspCtgryNo=SFMA41A02A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=5&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1



#회색(96개)-회색/짙은회색/밝은회색
n=1
while True:
    browser.get('https://www.ssfshop.com/Shirts/list?dspCtgryNo=SFMA41A02A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=3%2C4%2C2&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
    
#노란색(84개)-노란색/레몬색/겨자색
n=1
while True:
    browser.get('https://www.ssfshop.com/Blouses/list?dspCtgryNo=SFMA41A02A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=E%2CF%2CG&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
#흰색(584개)-흰색/아이보리
n=1
while True:
    browser.get('https://www.ssfshop.com/Blouses/list?dspCtgryNo=SFMA41A02A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=1%2C0&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1    

    
    
#초록색(127개)-카키/녹색/연두색/올리브/애플그린
n=1
while True:
    browser.get('https://www.ssfshop.com/Blouses/list?dspCtgryNo=SFMA41A02A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=L%2CH%2CM%2CK%2CJ&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
    
    
#파란색(380개)-하늘색/파란색/로열블루/남색
n=1
while True:
    browser.get('https://www.ssfshop.com/Blouses/list?dspCtgryNo=SFMA41A02A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=Q%2CR%2CP%2CN&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    

    
#보라색(59개)-와인/라벤다/연보라/보라/자주
n=1
while True:
    browser.get('https://www.ssfshop.com/Blouses/list?dspCtgryNo=SFMA41A02A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=T%2CV%2CZ%2CS%2CU&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
    
#빨간색(34개)-빨간색
n=1
while True:
    browser.get('https://www.ssfshop.com/Blouses/list?dspCtgryNo=SFMA41A02A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=6&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
#분홍색(121개)-연분홍/분홍/코랄/진분홍
n=1
while True:
    browser.get('https://www.ssfshop.com/Blouses/list?dspCtgryNo=SFMA41A02A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=Y%2CX%2C7%2CW&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
#갈색(94개)-진한갈색/갈색/황토색
n=1
while True:
    browser.get('https://www.ssfshop.com/Blouses/list?dspCtgryNo=SFMA41A02A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=D%2CB%2CC&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
print(len(img_link))
print(len(like_list))

#https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage=2&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=3%2C2%2C4&materNM=&cateViewOn=&cateNo=&fitPsbYn=N
# Out:
# 1908
# 1908

# %% [markdown]
# ### 니트(풀오버)

# %%
n=1
img_link=[]
like_list=[]

#검정(460개)
while True:
    browser.get('https://www.ssfshop.com/Pullovers/list?dspCtgryNo=SFMA41A03A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=5&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1



#회색(327개)-회색/짙은회색/밝은회색
n=1
while True:
    browser.get('https://www.ssfshop.com/Pullovers/list?dspCtgryNo=SFMA41A03A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=3%2C2%2C4&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
    
#노란색(103개)-노란색/레몬색/겨자색
n=1
while True:
    browser.get('https://www.ssfshop.com/Pullovers/list?dspCtgryNo=SFMA41A03A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=E%2CG%2CF&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

   
#흰색(538개)-흰색/아이보리
n=1
while True:
    browser.get('https://www.ssfshop.com/Pullovers/list?dspCtgryNo=SFMA41A03A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=0%2C1&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1    

    
    
#초록색(257개)-카키/녹색/연두색/올리브/애플그린
n=1
while True:
    browser.get('https://www.ssfshop.com/Pullovers/list?dspCtgryNo=SFMA41A03A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=M%2CH%2CL%2CK%2CJ&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
    
    
#파란색(406개)-하늘색/파란색/로열블루/남색
n=1
while True:
    browser.get('https://www.ssfshop.com/Pullovers/list?dspCtgryNo=SFMA41A03A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=R%2CQ%2CP%2CN&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    

     
#보라색(120개)-와인/라벤다/연보라/보라/자주
n=1
while True:
    browser.get('https://www.ssfshop.com/Pullovers/list?dspCtgryNo=SFMA41A03A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=V%2CT%2CZ%2CS%2CU&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
    
#빨간색(43개)-빨간색
n=1
while True:
    browser.get('https://www.ssfshop.com/Pullovers/list?dspCtgryNo=SFMA41A03A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=6&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
#분홍색(155개)-연분홍/분홍/코랄/진분홍
n=1
while True:
    browser.get('https://www.ssfshop.com/Pullovers/list?dspCtgryNo=SFMA41A03A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=Y%2CX%2C7%2CW&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
#갈색(274개)-진한갈색/갈색/황토색
n=1
while True:
    browser.get('https://www.ssfshop.com/Pullovers/list?dspCtgryNo=SFMA41A03A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=D%2CB%2CC&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
print(len(img_link))
print(len(like_list))

#https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage=2&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=3%2C2%2C4&materNM=&cateViewOn=&cateNo=&fitPsbYn=N
# Out:
# 2683
# 2683

# %%
img_link=[]
like_list=[]
while True:
    browser.get('https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage='+ str(n) +'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=3%2C2%2C4&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

print(len(img_link))
print(len(like_list))

#https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage=2&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=3%2C2%2C4&materNM=&cateViewOn=&cateNo=&fitPsbYn=N

# %% [markdown]
# ### 긴팔티셔츠

# %%
n=1
img_link=[]
like_list=[]

#검정(480개)
for i in range(1,9):
    browser.get('https://www.ssfshop.com/Long-Sleeve/list?dspCtgryNo=SFMA41A01A03&brandShopNo=&brndShopId=&currentPage='+str(i)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=5&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1



#회색(480개)-회색/짙은회색/밝은회색
n=1
for i in range(1,9):
    browser.get('https://www.ssfshop.com/Long-Sleeve/list?dspCtgryNo=SFMA41A01A03&brandShopNo=&brndShopId=&currentPage='+str(i)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=2%2C3%2C4&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
    
#노란색(125개)-노란색/레몬색/겨자색
n=1
while True:
    browser.get('https://www.ssfshop.com/Long-Sleeve/list?dspCtgryNo=SFMA41A01A03&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=E%2CG%2CF&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
#흰색(480개)-흰색/아이보리
n=1
for i in range(1,9):
    browser.get('https://www.ssfshop.com/Long-Sleeve/list?dspCtgryNo=SFMA41A01A03&brandShopNo=&brndShopId=&currentPage='+str(i)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=1%2C0&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1    

    
    
#초록색(356개)-카키/녹색/연두색/올리브/애플그린
n=1
while True:
    browser.get('https://www.ssfshop.com/Long-Sleeve/list?dspCtgryNo=SFMA41A01A03&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=M%2CH%2CL%2CK%2CJ&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
    
    
#파란색(480개)-하늘색/파란색/로열블루/남색
n=1
for i in range(1,9):
    browser.get('https://www.ssfshop.com/Long-Sleeve/list?dspCtgryNo=SFMA41A01A03&brandShopNo=&brndShopId=&currentPage='+str(i)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=R%2CQ%2CP%2CN&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    

     
#보라색(176개)-와인/라벤다/연보라/보라/자주
n=1
while True:
    browser.get('https://www.ssfshop.com/Long-Sleeve/list?dspCtgryNo=SFMA41A01A03&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=Z%2CS%2CV%2CT%2CU&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
    
#빨간색(89개)-빨간색
n=1
while True:
    browser.get('https://www.ssfshop.com/Long-Sleeve/list?dspCtgryNo=SFMA41A01A03&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=6&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
#분홍색(192개)-연분홍/분홍/코랄/진분홍
n=1
while True:
    browser.get('https://www.ssfshop.com/Long-Sleeve/list?dspCtgryNo=SFMA41A01A03&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=Y%2CX%2C7%2CW&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
#갈색(173개)-진한갈색/갈색/황토색
n=1
while True:
    browser.get('https://www.ssfshop.com/Long-Sleeve/list?dspCtgryNo=SFMA41A01A03&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=D%2CB%2CC&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
print(len(img_link))
print(len(like_list))

#https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage=2&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=3%2C2%2C4&materNM=&cateViewOn=&cateNo=&fitPsbYn=N
# Out:
# 3031
# 3031

# %% [markdown]
# ### 반팔티

# %%
n=1
img_link=[]
like_list=[]

#검정(480개)
for i in range(1,9):
    browser.get('https://www.ssfshop.com/Short-Sleeve/list?dspCtgryNo=SFMA41A01A02&brandShopNo=&brndShopId=&currentPage='+str(i)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=5&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1



#회색(227개)-회색/짙은회색/밝은회색
n=1
while True:
    browser.get('https://www.ssfshop.com/Short-Sleeve/list?dspCtgryNo=SFMA41A01A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=2%2C4%2C3&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
    
#노란색(141개)-노란색/레몬색/겨자색
n=1
while True:
    browser.get('https://www.ssfshop.com/Short-Sleeve/list?dspCtgryNo=SFMA41A01A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=E%2CF%2CG&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
#흰색(480개)-흰색/아이보리
n=1
for i in range(1,9):
    browser.get('https://www.ssfshop.com/Short-Sleeve/list?dspCtgryNo=SFMA41A01A02&brandShopNo=&brndShopId=&currentPage='+str(i)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=1%2C0&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1    

    
    
#초록색(306개)-카키/녹색/연두색/올리브/애플그린
n=1
while True:
    browser.get('https://www.ssfshop.com/Short-Sleeve/list?dspCtgryNo=SFMA41A01A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=M%2CL%2CH%2CK%2CJ&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
    
    
#파란색(454개)-하늘색/파란색/로열블루/남색
n=1
while True:
    browser.get('https://www.ssfshop.com/Short-Sleeve/list?dspCtgryNo=SFMA41A01A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=R%2CQ%2CN%2CP&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    

     
#보라색(111개)-와인/라벤다/연보라/보라/자주
n=1
while True:
    browser.get('https://www.ssfshop.com/Short-Sleeve/list?dspCtgryNo=SFMA41A01A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=T%2CV%2CS%2CZ%2CU&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
    
#빨간색(58개)-빨간색
n=1
while True:
    browser.get('https://www.ssfshop.com/Short-Sleeve/list?dspCtgryNo=SFMA41A01A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=6&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
#분홍색(211개)-연분홍/분홍/코랄/진분홍
n=1
while True:
    browser.get('https://www.ssfshop.com/Short-Sleeve/list?dspCtgryNo=SFMA41A01A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=X%2CY%2C7%2CW&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
#갈색(50개)-진한갈색/갈색/황토색
n=1
while True:
    browser.get('https://www.ssfshop.com/Short-Sleeve/list?dspCtgryNo=SFMA41A01A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=D%2CC%2CB&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
print(len(img_link))
print(len(like_list))

#https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage=2&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=3%2C2%2C4&materNM=&cateViewOn=&cateNo=&fitPsbYn=N
# Out:
# 2518
# 2518

# %% [markdown]
# ### 자켓

# %%
n=1
img_link=[]
like_list=[]

#검정(492개)
while True:
    browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=5&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1



#회색(221개)-회색/짙은회색/밝은회색
n=1
while True:
    browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=4%2C3%2C2&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
    
#노란색(44개)-노란색/레몬색/겨자색
n=1
while True:
    browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=E%2CG%2CF&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
#흰색(222개)-흰색/아이보리
n=1
while True:
    browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=0%2C1&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1    

    
    
#초록색(178개)-카키/녹색/연두색/올리브/애플그린
n=1
while True:
    browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=H%2CM%2CJ%2CL%2CK&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
    
    
#파란색(301개)-하늘색/파란색/로열블루/남색
n=1
while True:
    browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=R%2CP%2CQ%2CN&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    

     
#보라색(29개)-와인/라벤다/연보라/보라/자주
n=1
while True:
    browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=Z%2CU%2CS%2CT%2CV&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
    
#빨간색(27개)-빨간색
n=1
while True:
    browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=6&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
#분홍색(52개)-연분홍/분홍/코랄/진분홍
n=1
while True:
    browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=X%2CY%2C7%2CW&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
#갈색(223개)-진한갈색/갈색/황토색
n=1
while True:
    browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=D%2CB%2CC&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
print(len(img_link))
print(len(like_list))

#https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage=2&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=3%2C2%2C4&materNM=&cateViewOn=&cateNo=&fitPsbYn=N
# Out:
# 1789
# 1789

# %% [markdown]
# ### 가죽자켓

# %%
n=1
img_link=[]
like_list=[]

#검정(98개)
while True:
    browser.get('https://www.ssfshop.com/Leather-Jackets/list?dspCtgryNo=SFMA41A21A04&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=5&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1



#회색(221개)-회색/짙은회색/밝은회색
# n=1
# while True:
#     browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=4%2C3%2C2&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
#     time.sleep(3)
    
#     # 사진 링크
#     img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
#     if len(img_tag) == 0:
#         break
#     for x in img_tag:
#         img_url= x.get_attribute('src')
#         img_link.append(img_url)

        
#     # 좋아요
#     like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
#     for x in like:
#         like_list.append(x.text)
          
#     # 
#     n+=1

    
    
#노란색(44개)-노란색/레몬색/겨자색
# n=1
# while True:
#     browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=E%2CG%2CF&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
#     time.sleep(3)
    
#     # 사진 링크
#     img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
#     if len(img_tag) == 0:
#         break
#     for x in img_tag:
#         img_url= x.get_attribute('src')
#         img_link.append(img_url)

        
#     # 좋아요
#     like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
#     for x in like:
#         like_list.append(x.text)
          
#     # 
#     n+=1

    
#흰색(28개)-흰색/아이보리
n=1
while True:
    browser.get('https://www.ssfshop.com/Leather-Jackets/list?dspCtgryNo=SFMA41A21A04&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=A%2C0%2C1&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1    

    
    
#초록색(178개)-카키/녹색/연두색/올리브/애플그린
# n=1
# while True:
#     browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=H%2CM%2CJ%2CL%2CK&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
#     time.sleep(3)
    
#     # 사진 링크
#     img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
#     if len(img_tag) == 0:
#         break
#     for x in img_tag:
#         img_url= x.get_attribute('src')
#         img_link.append(img_url)

        
#     # 좋아요
#     like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
#     for x in like:
#         like_list.append(x.text)
          
#     # 
#     n+=1
    
    
    
#파란색(301개)-하늘색/파란색/로열블루/남색
# n=1
# while True:
#     browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=R%2CP%2CQ%2CN&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
#     time.sleep(3)
    
#     # 사진 링크
#     img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
#     if len(img_tag) == 0:
#         break
#     for x in img_tag:
#         img_url= x.get_attribute('src')
#         img_link.append(img_url)

        
#     # 좋아요
#     like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
#     for x in like:
#         like_list.append(x.text)
          
#     # 
#     n+=1
    

     
#보라색(29개)-와인/라벤다/연보라/보라/자주
# n=1
# while True:
#     browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=Z%2CU%2CS%2CT%2CV&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
#     time.sleep(3)
    
#     # 사진 링크
#     img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
#     if len(img_tag) == 0:
#         break
#     for x in img_tag:
#         img_url= x.get_attribute('src')
#         img_link.append(img_url)

        
#     # 좋아요
#     like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
#     for x in like:
#         like_list.append(x.text)
          
#     # 
#     n+=1
    
    
#빨간색(27개)-빨간색
# n=1
# while True:
#     browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=6&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
#     time.sleep(3)
    
#     # 사진 링크
#     img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
#     if len(img_tag) == 0:
#         break
#     for x in img_tag:
#         img_url= x.get_attribute('src')
#         img_link.append(img_url)

        
#     # 좋아요
#     like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
#     for x in like:
#         like_list.append(x.text)
          
#     # 
#     n+=1

    
#분홍색(4개)-연분홍/분홍/코랄/진분홍
n=1
while True:
    browser.get('https://www.ssfshop.com/Leather-Jackets/list?dspCtgryNo=SFMA41A21A04&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=7%2CY&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
#갈색(25개)-진한갈색/갈색/황토색
n=1
while True:
    browser.get('https://www.ssfshop.com/Leather-Jackets/list?dspCtgryNo=SFMA41A21A04&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=D%2CC%2CB&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
print(len(img_link))
print(len(like_list))

#https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage=2&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=3%2C2%2C4&materNM=&cateViewOn=&cateNo=&fitPsbYn=N
# Out:
# 155
# 155

# %% [markdown]
# ## 코트

# %%
n=1
img_link=[]
like_list=[]

#검정(365개)
while True:
    browser.get('https://www.ssfshop.com/Coats/list?dspCtgryNo=SFMA41A07A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=5&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1



#회색(238개)-회색/짙은회색/밝은회색
n=1
while True:
    browser.get('https://www.ssfshop.com/Coats/list?dspCtgryNo=SFMA41A07A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=3%2C2%2C4&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
    
#노란색(33개)-노란색/레몬색/겨자색
n=1
while True:
    browser.get('https://www.ssfshop.com/Coats/list?dspCtgryNo=SFMA41A07A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=G%2CE%2CF&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
#흰색(148개)-흰색/아이보리
n=1
while True:
    browser.get('https://www.ssfshop.com/Coats/list?dspCtgryNo=SFMA41A07A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=0%2C1&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1    

    
    
#초록색(141개)-카키/녹색/연두색/올리브/애플그린
n=1
while True:
    browser.get('https://www.ssfshop.com/Coats/list?dspCtgryNo=SFMA41A07A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=H%2CJ%2CM%2CL%2CK&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
    
    
#파란색(231개)-하늘색/파란색/로열블루/남색
n=1
while True:
    browser.get('https://www.ssfshop.com/Coats/list?dspCtgryNo=SFMA41A07A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=R%2CQ%2CP%2CN&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    

     
#보라색(25개)-와인/라벤다/연보라/보라/자주
n=1
while True:
    browser.get('https://www.ssfshop.com/Coats/list?dspCtgryNo=SFMA41A07A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=Z%2CT%2CV%2CS%2CU&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
    
#빨간색(17개)-빨간색
n=1
while True:
    browser.get('https://www.ssfshop.com/Coats/list?dspCtgryNo=SFMA41A07A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=6&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
#분홍색(35개)-연분홍/분홍/코랄/진분홍
n=1
while True:
    browser.get('https://www.ssfshop.com/Coats/list?dspCtgryNo=SFMA41A07A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=Y%2CX%2C7%2CW&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
#갈색(295개)-진한갈색/갈색/황토색
n=1
while True:
    browser.get('https://www.ssfshop.com/Coats/list?dspCtgryNo=SFMA41A07A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=D%2CB%2CC&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
print(len(img_link))
print(len(like_list))

#https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage=2&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=3%2C2%2C4&materNM=&cateViewOn=&cateNo=&fitPsbYn=N
# Out:
# 1528
# 1528

# %% [markdown]
# ## 점퍼

# %%
n=1
img_link=[]
like_list=[]

#검정(218개)
while True:
    browser.get('https://www.ssfshop.com/Jumpers/list?dspCtgryNo=SFMA41A07A03&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=5&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1



#회색(87개)-회색/짙은회색/밝은회색
n=1
while True:
    browser.get('https://www.ssfshop.com/Jumpers/list?dspCtgryNo=SFMA41A07A03&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=3%2C4%2C2&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

  
    
#노란색(12개)-노란색/레몬색/겨자색
n=1
while True:
    browser.get('https://www.ssfshop.com/Jumpers/list?dspCtgryNo=SFMA41A07A03&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=E%2CG%2CF&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1


    
#흰색(129개)-흰색/아이보리
n=1
while True:
    browser.get('https://www.ssfshop.com/Jumpers/list?dspCtgryNo=SFMA41A07A03&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=0%2C1&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          

    n+=1    

   
    
#초록색(122개)-카키/녹색/연두색/올리브/애플그린
n=1
while True:
    browser.get('https://www.ssfshop.com/Jumpers/list?dspCtgryNo=SFMA41A07A03&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=H%2CM%2CJ%2CL%2CK&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
   
    
#파란색(140개)-하늘색/파란색/로열블루/남색
n=1
while True:
    browser.get('https://www.ssfshop.com/Jumpers/list?dspCtgryNo=SFMA41A07A03&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=R%2CN%2CQ%2CP&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1



     
#보라색(19개)-와인/라벤다/연보라/보라/자주
n=1
while True:
    browser.get('https://www.ssfshop.com/Jumpers/list?dspCtgryNo=SFMA41A07A03&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=S%2CV%2CZ%2CT%2CU&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1


    
#빨간색(17개)-빨간색
n=1
while True:
    browser.get('https://www.ssfshop.com/Jumpers/list?dspCtgryNo=SFMA41A07A03&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=6&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1


    
#분홍색(32개)-연분홍/분홍/코랄/진분홍
n=1
while True:
    browser.get('https://www.ssfshop.com/Jumpers/list?dspCtgryNo=SFMA41A07A03&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=Y%2CX%2C7%2CW&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1


    
#갈색(62개)-진한갈색/갈색/황토색
n=1
while True:
    browser.get('https://www.ssfshop.com/Jumpers/list?dspCtgryNo=SFMA41A07A03&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=D%2CB%2CC&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
# img없는 like행 지워주기
like_list.pop(423)
len(like_list)

print(len(img_link))
print(len(like_list))




#https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage=2&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=3%2C2%2C4&materNM=&cateViewOn=&cateNo=&fitPsbYn=N
# Out:
# 218
# 218
# 305
# 305
# 317
# 317
# 446
# 447
# 568
# 569
# 708
# 709
# 727
# 728
# 744
# 745
# 776
# 777
# 838
# 839

# %%
# Out:
# 838

# %%
img_link=[]
like_list=[]

browser.get('https://www.ssfshop.com/Jumpers/list?dspCtgryNo=SFMA41A07A03&brandShopNo=&brndShopId=&currentPage=2&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=0%2C1&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
time.sleep(3)

# 사진 링크
img_tag=browser.find_elements_by_css_selector('#dspGood > li:nth-child(47) > a > img')
for x in img_tag:
    img=x.get_attribute('src')
    print(img)
# Out:
# https://www.ssfshop.com/v3/images/common/noImg_1500.gif

# %%
#dspGood > li:nth-child(47) > a > img

# %%
######셔츠
black=['검정색' for i in range(460)]
gray=['회색' for i in range(327)]
yellow=['노란색' for i in range(103)]
white=['흰색' for i in range(538)]
green=['초록색' for i in range(141)]
blue=['파란색' for i in range(424)]
purple=['보라색' for i in range(40)]
red=['빨간색' for i in range(37)]
pink=['분홍색' for i in range(76)]
brown=['갈색' for i in range(75)]

color = black+gray+yellow+white+green+blue+purple+red+pink+brown
len(color)
# Out:
# 1636

# %%
######블라우스
black=['검정색' for i in range(329)]
gray=['회색' for i in range(96)]
yellow=['노란색' for i in range(84)]
white=['흰색' for i in range(584)]
green=['초록색' for i in range(127)]
blue=['파란색' for i in range(380)]
purple=['보라색' for i in range(59)]
red=['빨간색' for i in range(34)]
pink=['분홍색' for i in range(121)]
brown=['갈색' for i in range(94)]

color = black+gray+yellow+white+green+blue+purple+red+pink+brown
len(color)
# Out:
# 1908

# %%
######니트(풀오버)
black=['검정색' for i in range(460)]
gray=['회색' for i in range(327)]
yellow=['노란색' for i in range(103)]
white=['흰색' for i in range(538)]
green=['초록색' for i in range(257)]
blue=['파란색' for i in range(406)]
purple=['보라색' for i in range(120)]
red=['빨간색' for i in range(43)]
pink=['분홍색' for i in range(155)]
brown=['갈색' for i in range(274)]

color = black+gray+yellow+white+green+blue+purple+red+pink+brown
len(color)
# Out:
# 2683

# %%
######긴팔티
black=['검정색' for i in range(480)]
gray=['회색' for i in range(480)]
yellow=['노란색' for i in range(125)]
white=['흰색' for i in range(480)]
green=['초록색' for i in range(356)]
blue=['파란색' for i in range(480)]
purple=['보라색' for i in range(176)]
red=['빨간색' for i in range(89)]
pink=['분홍색' for i in range(192)]
brown=['갈색' for i in range(173)]

color = black+gray+yellow+white+green+blue+purple+red+pink+brown
len(color)
# Out:
# 3031

# %%
######반팔티
black=['검정색' for i in range(480)]
gray=['회색' for i in range(227)]
yellow=['노란색' for i in range(141)]
white=['흰색' for i in range(480)]
green=['초록색' for i in range(306)]
blue=['파란색' for i in range(454)]
purple=['보라색' for i in range(111)]
red=['빨간색' for i in range(58)]
pink=['분홍색' for i in range(211)]
brown=['갈색' for i in range(50)]

color = black+gray+yellow+white+green+blue+purple+red+pink+brown
len(color)
# Out:
# 2518

# %%
######자켓
black=['검정색' for i in range(492)]
gray=['회색' for i in range(221)]
yellow=['노란색' for i in range(44)]
white=['흰색' for i in range(222)]
green=['초록색' for i in range(178)]
blue=['파란색' for i in range(301)]
purple=['보라색' for i in range(29)]
red=['빨간색' for i in range(27)]
pink=['분홍색' for i in range(52)]
brown=['갈색' for i in range(223)]

color = black+gray+yellow+white+green+blue+purple+red+pink+brown
len(color)
# Out:
# 1789

# %%
######가죽자켓
black=['검정색' for i in range(98)]
# gray=['회색' for i in range(221)]
# yellow=['노란색' for i in range(44)]
white=['흰색' for i in range(28)]
# green=['초록색' for i in range(178)]
# blue=['파란색' for i in range(301)]
# purple=['보라색' for i in range(29)]
# red=['빨간색' for i in range(27)]
pink=['분홍색' for i in range(4)]
brown=['갈색' for i in range(25)]

color = black+white+pink+brown
len(color)
# Out:
# 155

# %%
######코트
black=['검정색' for i in range(365)]
gray=['회색' for i in range(238)]
yellow=['노란색' for i in range(33)]
white=['흰색' for i in range(148)]
green=['초록색' for i in range(141)]
blue=['파란색' for i in range(231)]
purple=['보라색' for i in range(25)]
red=['빨간색' for i in range(17)]
pink=['분홍색' for i in range(35)]
brown=['갈색' for i in range(295)]

color = black+gray+yellow+white+green+blue+purple+red+pink+brown
len(color)
# Out:
# 1528

# %%
######점퍼
black=['검정색' for i in range(218)]
gray=['회색' for i in range(87)]
yellow=['노란색' for i in range(12)]
white=['흰색' for i in range(129)]
green=['초록색' for i in range(122)]
blue=['파란색' for i in range(140)]
purple=['보라색' for i in range(19)]
red=['빨간색' for i in range(17)]
pink=['분홍색' for i in range(32)]
brown=['갈색' for i in range(62)]

color = black+gray+yellow+white+green+blue+purple+red+pink+brown
len(color)
# Out:
# 838

# %%
218 87 12 130 122 140 19 17 32 62

# %% [markdown]
# ## 데이터프레임 생성

# %%
##########가디건
import csv
# color=[]
category=[]
# for x in range(len(like_list)):
#     color.append('회색')
for x in range(len(like_list)):
    category.append('가디건')

with open('C:/Temp/크롤링/8seconds/가디건/cardigan.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['img','like','color','type'])
    for i in range(len(img_link)):
        writer.writerow((img_link[i],like_list[i],color[i],category[i]))

cardigan=pd.read_csv('C:/Temp/크롤링/8seconds/가디건/cardigan.csv')
# ind=list(range(1,142))
# ess_gray_cardigan['index']=ind
cardigan
# Out:
#                                                    img   like color type
# 0    https://img.ssfshop.com/cmd/LB_500x660/src/htt...   81.0   검정색  가디건
# 1    https://img.ssfshop.com/cmd/LB_500x660/src/htt...  146.0   검정색  가디건
# 2    https://img.ssfshop.com/cmd/LB_500x660/src/htt...   93.0   검정색  가디건
# 3    https://img.ssfshop.com/cmd/LB_500x660/src/htt...  102.0   검정색  가디건
# 4    https://img.ssfshop.com/cmd/LB_500x660/src/htt...   45.0   검정색  가디건
# ..                                                 ...    ...   ...  ...
# 965  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    NaN    갈색  가디건
# 966  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    1.0    갈색  가디건
# 967  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    4.0    갈색  가디건
# 968  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    2.0    갈색  가디건
# 969  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    NaN    갈색  가디건
#
# [970 rows x 4 columns]

# %%
###########셔츠
import csv
# color=[]
category=[]
# for x in range(len(like_list)):
#     color.append('회색')
for x in range(len(like_list)):
    category.append('셔츠')

with open('C:/Temp/크롤링/8seconds/셔츠/shirts.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['img','like','color','type'])
    for i in range(len(img_link)):
        writer.writerow((img_link[i],like_list[i],color[i],category[i]))

shirts=pd.read_csv('C:/Temp/크롤링/8seconds/셔츠/shirts.csv')
# ind=list(range(1,142))
# ess_gray_cardigan['index']=ind
shirts
# Out:
#                                                     img  like color type
# 0     https://img.ssfshop.com/cmd/LB_500x660/src/htt...  34.0   검정색   셔츠
# 1     https://img.ssfshop.com/cmd/LB_500x660/src/htt...  82.0   검정색   셔츠
# 2     https://img.ssfshop.com/cmd/LB_500x660/src/htt...  36.0   검정색   셔츠
# 3     https://img.ssfshop.com/cmd/LB_500x660/src/htt...  45.0   검정색   셔츠
# 4     https://img.ssfshop.com/cmd/LB_500x660/src/htt...   1.0   검정색   셔츠
# ...                                                 ...   ...   ...  ...
# 1631  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   NaN    갈색   셔츠
# 1632  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   NaN    갈색   셔츠
# 1633  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   NaN    갈색   셔츠
# 1634  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   NaN    갈색   셔츠
# 1635  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   NaN    갈색   셔츠
#
# [1636 rows x 4 columns]

# %%
###########블라우스
import csv
# color=[]
category=[]
# for x in range(len(like_list)):
#     color.append('회색')
for x in range(len(like_list)):
    category.append('블라우스')

with open('C:/Temp/크롤링/8seconds/블라우스/blouses.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['img','like','color','type'])
    for i in range(len(img_link)):
        writer.writerow((img_link[i],like_list[i],color[i],category[i]))

blouses=pd.read_csv('C:/Temp/크롤링/8seconds/블라우스/blouses.csv')
# ind=list(range(1,142))
# ess_gray_cardigan['index']=ind
blouses
# Out:
#                                                     img   like color  type
# 0     https://img.ssfshop.com/cmd/LB_500x660/src/htt...   90.0   검정색  블라우스
# 1     https://img.ssfshop.com/cmd/LB_500x660/src/htt...   77.0   검정색  블라우스
# 2     https://img.ssfshop.com/cmd/LB_500x660/src/htt...  304.0   검정색  블라우스
# 3     https://img.ssfshop.com/cmd/LB_500x660/src/htt...  192.0   검정색  블라우스
# 4     https://img.ssfshop.com/cmd/LB_500x660/src/htt...  136.0   검정색  블라우스
# ...                                                 ...    ...   ...   ...
# 1903  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    NaN    갈색  블라우스
# 1904  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    NaN    갈색  블라우스
# 1905  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    NaN    갈색  블라우스
# 1906  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    2.0    갈색  블라우스
# 1907  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    1.0    갈색  블라우스
#
# [1908 rows x 4 columns]

# %%
###########니트(풀오버)
import csv
# color=[]
category=[]
# for x in range(len(like_list)):
#     color.append('회색')
for x in range(len(like_list)):
    category.append('니트')

with open('C:/Temp/크롤링/8seconds/니트/pullover.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['img','like','color','type'])
    for i in range(len(img_link)):
        writer.writerow((img_link[i],like_list[i],color[i],category[i]))

pullover=pd.read_csv('C:/Temp/크롤링/8seconds/니트/pullover.csv')
# ind=list(range(1,142))
# ess_gray_cardigan['index']=ind
pullover
# Out:
#                                                     img   like color type
# 0     https://img.ssfshop.com/cmd/LB_500x660/src/htt...  154.0   검정색   니트
# 1     https://img.ssfshop.com/cmd/LB_500x660/src/htt...  147.0   검정색   니트
# 2     https://img.ssfshop.com/cmd/LB_500x660/src/htt...  101.0   검정색   니트
# 3     https://img.ssfshop.com/cmd/LB_500x660/src/htt...  105.0   검정색   니트
# 4     https://img.ssfshop.com/cmd/LB_500x660/src/htt...   39.0   검정색   니트
# ...                                                 ...    ...   ...  ...
# 2678  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    NaN    갈색   니트
# 2679  https://img.ssfshop.com/cmd/LB_500x660/src/htt...  408.0    갈색   니트
# 2680  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   97.0    갈색   니트
# 2681  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   32.0    갈색   니트
# 2682  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    3.0    갈색   니트
#
# [2683 rows x 4 columns]

# %%
###########긴팔티
import csv
# color=[]
category=[]
# for x in range(len(like_list)):
#     color.append('회색')
for x in range(len(like_list)):
    category.append('긴팔티')

with open('C:/Temp/크롤링/8seconds/긴팔티/long_sleeve.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['img','like','color','type'])
    for i in range(len(img_link)):
        writer.writerow((img_link[i],like_list[i],color[i],category[i]))

long_sleeve=pd.read_csv('C:/Temp/크롤링/8seconds/긴팔티/long_sleeve.csv')
# ind=list(range(1,142))
# ess_gray_cardigan['index']=ind
long_sleeve
# Out:
#                                                     img   like color type
# 0     https://img.ssfshop.com/cmd/LB_500x660/src/htt...   50.0   검정색  긴팔티
# 1     https://img.ssfshop.com/cmd/LB_500x660/src/htt...  105.0   검정색  긴팔티
# 2     https://img.ssfshop.com/cmd/LB_500x660/src/htt...   32.0   검정색  긴팔티
# 3     https://img.ssfshop.com/cmd/LB_500x660/src/htt...   24.0   검정색  긴팔티
# 4     https://img.ssfshop.com/cmd/LB_500x660/src/htt...  108.0   검정색  긴팔티
# ...                                                 ...    ...   ...  ...
# 3026  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    NaN    갈색  긴팔티
# 3027  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    NaN    갈색  긴팔티
# 3028  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    NaN    갈색  긴팔티
# 3029  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    NaN    갈색  긴팔티
# 3030  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    NaN    갈색  긴팔티
#
# [3031 rows x 4 columns]

# %%
###########반팔티
import csv
# color=[]
category=[]
# for x in range(len(like_list)):
#     color.append('회색')
for x in range(len(like_list)):
    category.append('반팔티')

with open('C:/Temp/크롤링/8seconds/반팔티/short_sleeve.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['img','like','color','type'])
    for i in range(len(img_link)):
        writer.writerow((img_link[i],like_list[i],color[i],category[i]))

short_sleeve=pd.read_csv('C:/Temp/크롤링/8seconds/반팔티/short_sleeve.csv')
# ind=list(range(1,142))
# ess_gray_cardigan['index']=ind
short_sleeve
# Out:
#                                                     img  like color type
# 0     https://img.ssfshop.com/cmd/LB_500x660/src/htt...  27.0   검정색  반팔티
# 1     https://img.ssfshop.com/cmd/LB_500x660/src/htt...  13.0   검정색  반팔티
# 2     https://img.ssfshop.com/cmd/LB_500x660/src/htt...  11.0   검정색  반팔티
# 3     https://img.ssfshop.com/cmd/LB_500x660/src/htt...  45.0   검정색  반팔티
# 4     https://img.ssfshop.com/cmd/LB_500x660/src/htt...  30.0   검정색  반팔티
# ...                                                 ...   ...   ...  ...
# 2513  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   2.0    갈색  반팔티
# 2514  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   NaN    갈색  반팔티
# 2515  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   NaN    갈색  반팔티
# 2516  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   NaN    갈색  반팔티
# 2517  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   NaN    갈색  반팔티
#
# [2518 rows x 4 columns]

# %%
###########자켓
import csv
# color=[]
category=[]
# for x in range(len(like_list)):
#     color.append('회색')
for x in range(len(like_list)):
    category.append('자켓')

with open('C:/Temp/크롤링/8seconds/자켓/jackets.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['img','like','color','type'])
    for i in range(len(img_link)):
        writer.writerow((img_link[i],like_list[i],color[i],category[i]))

jackets=pd.read_csv('C:/Temp/크롤링/8seconds/자켓/jackets.csv')
# ind=list(range(1,142))
# ess_gray_cardigan['index']=ind
jackets
# Out:
#                                                     img   like color type
# 0     https://img.ssfshop.com/cmd/LB_500x660/src/htt...   35.0   검정색   자켓
# 1     https://img.ssfshop.com/cmd/LB_500x660/src/htt...  169.0   검정색   자켓
# 2     https://img.ssfshop.com/cmd/LB_500x660/src/htt...   48.0   검정색   자켓
# 3     https://img.ssfshop.com/cmd/LB_500x660/src/htt...  286.0   검정색   자켓
# 4     https://img.ssfshop.com/cmd/LB_500x660/src/htt...   46.0   검정색   자켓
# ...                                                 ...    ...   ...  ...
# 1784  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    1.0    갈색   자켓
# 1785  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    1.0    갈색   자켓
# 1786  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    1.0    갈색   자켓
# 1787  https://img.ssfshop.com/cmd/LB_500x660/src/htt...  537.0    갈색   자켓
# 1788  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   10.0    갈색   자켓
#
# [1789 rows x 4 columns]

# %%
###########가죽자켓
import csv
# color=[]
category=[]
# for x in range(len(like_list)):
#     color.append('회색')
for x in range(len(like_list)):
    category.append('가죽자켓')

with open('C:/Temp/크롤링/8seconds/가죽자켓/leather_jackets.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['img','like','color','type'])
    for i in range(len(img_link)):
        writer.writerow((img_link[i],like_list[i],color[i],category[i]))

leather_jackets=pd.read_csv('C:/Temp/크롤링/8seconds/가죽자켓/leather_jackets.csv')
# ind=list(range(1,142))
# ess_gray_cardigan['index']=ind
leather_jackets
# Out:
#                                                    img   like color  type
# 0    https://img.ssfshop.com/cmd/LB_500x660/src/htt...   94.0   검정색  가죽자켓
# 1    https://img.ssfshop.com/cmd/LB_500x660/src/htt...  169.0   검정색  가죽자켓
# 2    https://img.ssfshop.com/cmd/LB_500x660/src/htt...   63.0   검정색  가죽자켓
# 3    https://img.ssfshop.com/cmd/LB_500x660/src/htt...   88.0   검정색  가죽자켓
# 4    https://img.ssfshop.com/cmd/LB_500x660/src/htt...   26.0   검정색  가죽자켓
# ..                                                 ...    ...   ...   ...
# 150  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    5.0    갈색  가죽자켓
# 151  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    3.0    갈색  가죽자켓
# 152  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    NaN    갈색  가죽자켓
# 153  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    4.0    갈색  가죽자켓
# 154  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    2.0    갈색  가죽자켓
#
# [155 rows x 4 columns]

# %%
###########코트
import csv
# color=[]
category=[]
# for x in range(len(like_list)):
#     color.append('회색')
for x in range(len(like_list)):
    category.append('코트')

with open('C:/Temp/크롤링/8seconds/코트/coat.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['img','like','color','type'])
    for i in range(len(img_link)):
        writer.writerow((img_link[i],like_list[i],color[i],category[i]))

coat=pd.read_csv('C:/Temp/크롤링/8seconds/코트/coat.csv')
# ind=list(range(1,142))
# ess_gray_cardigan['index']=ind
coat
# Out:
#                                                     img   like color type
# 0     https://img.ssfshop.com/cmd/LB_500x660/src/htt...  179.0   검정색   코트
# 1     https://img.ssfshop.com/cmd/LB_500x660/src/htt...  175.0   검정색   코트
# 2     https://img.ssfshop.com/cmd/LB_500x660/src/htt...  429.0   검정색   코트
# 3     https://img.ssfshop.com/cmd/LB_500x660/src/htt...   93.0   검정색   코트
# 4     https://img.ssfshop.com/cmd/LB_500x660/src/htt...  137.0   검정색   코트
# ...                                                 ...    ...   ...  ...
# 1523  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    5.0    갈색   코트
# 1524  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    9.0    갈색   코트
# 1525  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   20.0    갈색   코트
# 1526  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   30.0    갈색   코트
# 1527  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    3.0    갈색   코트
#
# [1528 rows x 4 columns]

# %%
###########점퍼
import csv
# color=[]
category=[]
# for x in range(len(like_list)):
#     color.append('회색')
for x in range(len(like_list)):
    category.append('점퍼')

with open('C:/Temp/크롤링/8seconds/점퍼/jumper.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['img','like','color','type'])
    for i in range(len(img_link)):
        writer.writerow((img_link[i],like_list[i],color[i],category[i]))

jumper=pd.read_csv('C:/Temp/크롤링/8seconds/점퍼/jumper.csv')
# ind=list(range(1,142))
# ess_gray_cardigan['index']=ind
jumper
# Out:
#                                                    img   like color type
# 0    https://img.ssfshop.com/cmd/LB_500x660/src/htt...  152.0   검정색   점퍼
# 1    https://img.ssfshop.com/cmd/LB_500x660/src/htt...   81.0   검정색   점퍼
# 2    https://img.ssfshop.com/cmd/LB_500x660/src/htt...  234.0   검정색   점퍼
# 3    https://img.ssfshop.com/cmd/LB_500x660/src/htt...  144.0   검정색   점퍼
# 4    https://img.ssfshop.com/cmd/LB_500x660/src/htt...  119.0   검정색   점퍼
# ..                                                 ...    ...   ...  ...
# 833  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    2.0    갈색   점퍼
# 834  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    2.0    갈색   점퍼
# 835  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    7.0    갈색   점퍼
# 836  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    1.0    갈색   점퍼
# 837  https://img.ssfshop.com/cmd/LB_500x660/src/htt...  108.0    갈색   점퍼
#
# [838 rows x 4 columns]

# %% [markdown]
# ## 사진저장

# %%
from urllib.request import urlopen
n=1
for img_src in img_link:
    if img_src == '':
        continue
    else:
        with urlopen(img_src) as f:
            # img라는 폴더 안에 programmer(n).jpg 파일을 저장한다.
            # 텍스트 파일이 아니기 때문에 w(write)만 쓰면 안되고 binary 모드를 추가시켜야 한다.
            with open('c:/Temp/크롤링/8seconds/' + str(n) + '.jpg', "wb") as h:
                # f를 읽고 img에 저장한다.
                img = f.read()
                # h에 위 내용을 쓴다.
                h.write(img)
        # 계속 programmer 1에 덮어쓰지 않도록 1을 증가시켜 준다
        n += 1

# %%
like_list

# %% [markdown]
# ## bs방법 사용

# %%
n=1
while True:
    req = requests.get('https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage='+ str(n) +'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=3%2C2%2C4&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    html = req.text
    soup = bs(browser.page_source,'html.parser')
    
    
    img_tag=soup.select_all('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    img_link=[]
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)
        
    n+=1

print(img_link)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-01fbe8bbbe40> in <module>
#       6
#       7
# ----> 8     img_tag=soup.select_all('#dspGood > li > a > span > img')
#       9     if len(img_tag) == 0:
#      10         break
#
# TypeError: 'NoneType' object is not callable
