# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import re
import numpy as np
from bs4 import BeautifulSoup as bs
import pickle
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
browser = webdriver.Chrome('C:/Temp/chromedriver')

# %%
## 초록######
n=1
img_link=[]

#아우터(369개)
while True:
    browser.get('https://www.ssfshop.com/Outerwear/list?dspCtgryNo=SFMA41A07&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=H%2CM%2CJ%2CL&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1


n=1
#재킷/베스트(206개)
while True:
    browser.get('https://www.ssfshop.com/Jackets-Vests/list?dspCtgryNo=SFMA41A21&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=H%2CM%2CJ%2CL&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1
    
n=1
#티셔츠(607개)
while True:
    browser.get('https://www.ssfshop.com/T-shirts/list?dspCtgryNo=SFMA41A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=M%2CH%2CL%2CJ&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1

n=1
#셔츠/블라우스(219개)    
while True:
    browser.get('https://www.ssfshop.com/Shirts-Blouses/list?dspCtgryNo=SFMA41A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=H%2CM%2CL%2CJ&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1

n=1
#니트(335개)    
while True:
    browser.get('https://www.ssfshop.com/Knitwear/list?dspCtgryNo=SFMA41A03&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=H%2CM%2CL%2CJ&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1

n=1
#원피스(264개)    
while True:
    browser.get('https://www.ssfshop.com/Dresses/list?dspCtgryNo=SFMA41A06&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=H%2CM%2CL%2CJ&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1

n=1
#팬츠(326개)    
while True:
    browser.get('https://www.ssfshop.com/Pants-Trousers/list?dspCtgryNo=SFMA41A04&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=H%2CM%2CJ%2CL&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1

n=1
#스커트(196개)    
while True:
    browser.get('https://www.ssfshop.com/Skirts/list?dspCtgryNo=SFMA41A05&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=H%2CM%2CL%2CJ&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1

    
len(img_link)

# %%
#####노랑######
n=1
#아우터(59개)
while True:
    browser.get('https://www.ssfshop.com/Outerwear/list?dspCtgryNo=SFMA41A07&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=G%2CE%2CF&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1


n=1
#재킷/베스트(48개)
while True:
    browser.get('https://www.ssfshop.com/Jackets-Vests/list?dspCtgryNo=SFMA41A21&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=E%2CG%2CF&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1
    
n=1
#티셔츠(285개)
while True:
    browser.get('https://www.ssfshop.com/T-shirts/list?dspCtgryNo=SFMA41A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=E%2CF%2CG&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1

n=1
#셔츠/블라우스(141개)    
while True:
    browser.get('https://www.ssfshop.com/Shirts-Blouses/list?dspCtgryNo=SFMA41A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=E%2CF%2CG&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1

n=1
#니트(152개)    
while True:
    browser.get('https://www.ssfshop.com/Knitwear/list?dspCtgryNo=SFMA41A03&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=E%2CG%2CF&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1

n=1
#원피스(125개)    
while True:
    browser.get('https://www.ssfshop.com/Dresses/list?dspCtgryNo=SFMA41A06&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=E%2CF%2CG&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1

n=1
#팬츠(74개)    
while True:
    browser.get('https://www.ssfshop.com/Pants-Trousers/list?dspCtgryNo=SFMA41A04&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=E%2CG%2CF&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1

n=1
#스커트(66개)    
while True:
    browser.get('https://www.ssfshop.com/Skirts/list?dspCtgryNo=SFMA41A05&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=E%2CF%2CG&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1

    
len(img_link)
# Out:
# 3472

# %%
#####분홍######
n=1
#아우터(91개)
while True:
    browser.get('https://www.ssfshop.com/Outerwear/list?dspCtgryNo=SFMA41A07&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=Y%2CX%2C7%2CW&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1


n=1
#재킷/베스트(66개)
while True:
    browser.get('https://www.ssfshop.com/Jackets-Vests/list?dspCtgryNo=SFMA41A21&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=Y%2CX%2C7%2CW&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1
    
n=1
#티셔츠(458개)
while True:
    browser.get('https://www.ssfshop.com/T-shirts/list?dspCtgryNo=SFMA41A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=X%2CY%2C7%2CW&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1

n=1
#셔츠/블라우스(178개)    
while True:
    browser.get('https://www.ssfshop.com/Shirts-Blouses/list?dspCtgryNo=SFMA41A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=Y%2CX%2C7%2CW&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1

n=1
#니트(198개)    
while True:
    browser.get('https://www.ssfshop.com/Knitwear/list?dspCtgryNo=SFMA41A03&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=X%2CY%2C7%2CW&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1

n=1
#원피스(160개)    
while True:
    browser.get('https://www.ssfshop.com/Dresses/list?dspCtgryNo=SFMA41A06&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=Y%2CX%2C7%2CW&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1

n=1
#팬츠(140개)    
while True:
    browser.get('https://www.ssfshop.com/Pants-Trousers/list?dspCtgryNo=SFMA41A04&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=Y%2CX%2C7%2CW&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1

n=1
#스커트(76개)    
while True:
    browser.get('https://www.ssfshop.com/Skirts/list?dspCtgryNo=SFMA41A05&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=X%2CY%2C7%2CW&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1

    
len(img_link)
# Out:
# 4839

# %%
#####보라######
n=1
#아우터(63개)
while True:
    browser.get('https://www.ssfshop.com/Outerwear/list?dspCtgryNo=SFMA41A07&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=U%2CZ%2CS%2CV&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1


n=1
#재킷/베스트(32개)
while True:
    browser.get('https://www.ssfshop.com/Jackets-Vests/list?dspCtgryNo=SFMA41A21&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=Z%2CU%2CS%2CV&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1
    
n=1
#티셔츠(237개)
while True:
    browser.get('https://www.ssfshop.com/T-shirts/list?dspCtgryNo=SFMA41A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=V%2CS%2CZ%2CU&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1

n=1
#셔츠/블라우스(68개)    
while True:
    browser.get('https://www.ssfshop.com/Shirts-Blouses/list?dspCtgryNo=SFMA41A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=S%2CZ%2CV%2CU&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1

n=1
#니트(125개)    
while True:
    browser.get('https://www.ssfshop.com/Knitwear/list?dspCtgryNo=SFMA41A03&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=V%2CZ%2CS%2CU&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1

n=1
#원피스(95개)    
while True:
    browser.get('https://www.ssfshop.com/Dresses/list?dspCtgryNo=SFMA41A06&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=Z%2CV%2CU%2CS&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1

n=1
#팬츠(80개)    
while True:
    browser.get('https://www.ssfshop.com/Pants-Trousers/list?dspCtgryNo=SFMA41A04&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=Z%2CV%2CS%2CU&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1

n=1
#스커트(42개)    
while True:
    browser.get('https://www.ssfshop.com/Skirts/list?dspCtgryNo=SFMA41A05&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=Z%2CU%2CV%2CS&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)


    n+=1

    
len(img_link)
# Out:
# 5581

# %%
5581

# %%
######
green=['초록색' for i in range(2522)]
yellow=['노란색' for i in range(950)]
pink=['분홍색' for i in range(1367)]
purple=['보라색' for i in range(742)]



color = green+yellow+pink+purple
len(color)
# Out:
# 5581

# %%
import csv

# color=[]
# for x in range(len(like_list)):
#     color.append('회색')
# for x in range(len(img_link)):
#     color.append('green')

with open('C:/Temp/크롤링/color.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['img','color'])
    for i in range(len(img_link)):
        writer.writerow((img_link[i],color[i]))

color_more=pd.read_csv('C:/Temp/크롤링/color.csv')
# ind=list(range(1,142))
# ess_gray_cardigan['index']=ind
color_more
# Out:
#                                                     img color
# 0     https://img.ssfshop.com/cmd/LB_500x660/src/htt...   초록색
# 1     https://img.ssfshop.com/cmd/LB_500x660/src/htt...   초록색
# 2     https://img.ssfshop.com/cmd/LB_500x660/src/htt...   초록색
# 3     https://img.ssfshop.com/cmd/LB_500x660/src/htt...   초록색
# 4     https://img.ssfshop.com/cmd/LB_500x660/src/htt...   초록색
# ...                                                 ...   ...
# 5576  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   보라색
# 5577  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   보라색
# 5578  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   보라색
# 5579  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   보라색
# 5580  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   보라색
#
# [5581 rows x 2 columns]

# %%
idx=[]
for i in range(21028,26609):
    idx.append(i)
len(idx)
# Out:
# 5581

# %%
color_more['index']=idx
color_more
color_more=color_more.drop('img',axis=1)
color_more
color_more=color_more[['index','color']]
color_more
# Out:
#       index color
# 0     21028   초록색
# 1     21029   초록색
# 2     21030   초록색
# 3     21031   초록색
# 4     21032   초록색
# ...     ...   ...
# 5576  26604   보라색
# 5577  26605   보라색
# 5578  26606   보라색
# 5579  26607   보라색
# 5580  26608   보라색
#
# [5581 rows x 2 columns]

# %%
color_more.to_csv('c:/Temp/크롤링/more/color2.csv',encoding='utf-8-sig',index=False)

# %%
from urllib.request import urlopen
n=21028
for img_src in img_link:
    if img_src == '':
        continue
    else:
        with urlopen(img_src) as f:
            # img라는 폴더 안에 programmer(n).jpg 파일을 저장한다.
            # 텍스트 파일이 아니기 때문에 w(write)만 쓰면 안되고 binary 모드를 추가시켜야 한다.
            with open('c:/Temp/크롤링/more/' + str(n) + '.jpg', "wb") as h:
                # f를 읽고 img에 저장한다.
                img = f.read()
                # h에 위 내용을 쓴다.
                h.write(img)
        # 계속 programmer 1에 덮어쓰지 않도록 1을 증가시켜 준다
        n += 1 
#26608

# %%
########################## 무신사

# %%
n=1
musinsa_list=[]
browser.get('https://search.musinsa.com/category/001?device=&d_cat_cd=001&brand=&rate=&page_kind=search&list_kind=small&sort=pop&sub_sort=&page=1&display_cnt=90&sale_goods=&ex_soldout=&color=6%2C34&price1=&price2=&exclusive_yn=&size=&tags=&sale_campaign_yn=&timesale_yn=&q=')
time.sleep(3)


# 사진 링크
musinsa=browser.find_elements_by_css_selector('#searchList > li > div.li_inner > div.list_img > a > img')
# if len(img_tag) == 0:
#     break
for x in musinsa:
    m_url= x.get_attribute('src')
    musinsa_list.append(m_url)

# %%
musinsa_list
# Out:
# ['https://image.msscdn.net/images/goods_img/20201216/1723668/1723668_1_125.jpg',
#  'https://image.msscdn.net/images/goods_img/20201216/1723495/1723495_1_125.jpg',
#  'https://image.msscdn.net/images/goods_img/20190812/1116155/1116155_3_125.jpg',
#  'https://image.msscdn.net/images/goods_img/20200305/1336836/1336836_13_125.jpg',
#  'https://image.msscdn.net/images/goods_img/20200824/1560192/1560192_2_125.jpg',
#  'https://image.msscdn.net/images/no_image_125.png',
#  'https://image.msscdn.net/images/no_image_125.png',
#  'https://image.msscdn.net/images/no_image_125.png',
#  'https://image.msscdn.net/images/no_image_125.png',
#  'https://image.msscdn.net/images/no_image_125.png',
#  'https://image.msscdn.net/images/no_image_125.png',
#  'https://image.msscdn.net/images/no_image_125.png',
#  'https://image.msscdn.net/images/no_image_125.png',
#  'https://image.msscdn.net/images/no_image_125.png',
#  'https://image.msscdn.net/images/no_image_125.png',
# ...

# %%
### 초록
n=1
musinsa_list=[]
while True:
    browser.get('https://search.musinsa.com/category/001?device=&d_cat_cd=001&brand=&rate=&page_kind=search&list_kind=small&sort=pop&sub_sort=&page='+str(n)+'&display_cnt=90&sale_goods=&ex_soldout=&color=6%2C34&price1=&price2=&exclusive_yn=&size=&tags=&sale_campaign_yn=&timesale_yn=&q=') 
    time.sleep(3)
    

    # 사진 링크
    musinsa=browser.find_elements_by_css_selector('#searchList > li > div.li_inner > div.list_img > a > img')
    # if len(img_tag) == 0:
    #     break
    for x in musinsa:
        m_url= x.get_attribute('src')
        musinsa_list.append(m_url)
   
    if n==25:
        break
    
    n+=1
len(musinsa_list)
# Out:
# 2250

# %%
##노랑
n=1
# musinsa_list=[]
while True:
    browser.get('https://search.musinsa.com/category/001?device=&d_cat_cd=001&brand=&rate=&page_kind=search&list_kind=small&sort=pop&sub_sort=&page='+str(n)+'&display_cnt=90&sale_goods=&ex_soldout=&color=9%2C44%2C43&price1=&price2=&exclusive_yn=&size=&tags=&sale_campaign_yn=&timesale_yn=&q=')
    time.sleep(3)
    

    # 사진 링크
    musinsa=browser.find_elements_by_css_selector('#searchList > li > div.li_inner > div.list_img > a > img')
    # if len(img_tag) == 0:
    #     break
    for x in musinsa:
        m_url= x.get_attribute('src')
        musinsa_list.append(m_url)
   
    if n==25:
        break
    
    n+=1
len(musinsa_list)
# Out:
# 4500

# %%
##분홍
n=1
# musinsa_list=[]
while True:
    browser.get('https://search.musinsa.com/category/001?device=&d_cat_cd=001&brand=&rate=&page_kind=search&list_kind=small&sort=pop&sub_sort=&page='+str(n)+'&display_cnt=90&sale_goods=&ex_soldout=&color=45%2C10%2C47&price1=&price2=&exclusive_yn=&size=&tags=&sale_campaign_yn=&timesale_yn=&q=')
    time.sleep(3)
    

    # 사진 링크
    musinsa=browser.find_elements_by_css_selector('#searchList > li > div.li_inner > div.list_img > a > img')
    # if len(img_tag) == 0:
    #     break
    for x in musinsa:
        m_url= x.get_attribute('src')
        musinsa_list.append(m_url)
   
    if n==25:
        break
    
    n+=1
len(musinsa_list)
# Out:
# 6750

# %%
##보라
n=1
# musinsa_list=[]
while True:
    browser.get('https://search.musinsa.com/category/001?device=&d_cat_cd=001&brand=&rate=&page_kind=search&list_kind=small&sort=pop&sub_sort=&page='+str(n)+'&display_cnt=90&sale_goods=&ex_soldout=&color=8%2C40%2C39&price1=&price2=&exclusive_yn=&size=&tags=&sale_campaign_yn=&timesale_yn=&q=')
    time.sleep(3)
    

    # 사진 링크
    musinsa=browser.find_elements_by_css_selector('#searchList > li > div.li_inner > div.list_img > a > img')
    # if len(img_tag) == 0:
    #     break
    for x in musinsa:
        m_url= x.get_attribute('src')
        musinsa_list.append(m_url)
   
    if n==25:
        break
    
    n+=1
len(musinsa_list)
# Out:
# 9000

# %%
######
green=['초록색' for i in range(2250)]
yellow=['노란색' for i in range(2250)]
pink=['분홍색' for i in range(2250)]
purple=['보라색' for i in range(2250)]



color = green+yellow+pink+purple
len(color)
# Out:
# 9000

# %%
import csv

# color=[]
# for x in range(len(like_list)):
#     color.append('회색')
# for x in range(len(img_link)):
#     color.append('green')

with open('C:/Temp/크롤링/color2.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['img','color'])
    for i in range(len(musinsa_list)):
        writer.writerow((musinsa_list[i],color[i]))

color_musinsa=pd.read_csv('C:/Temp/크롤링/color2.csv')
# ind=list(range(1,142))
# ess_gray_cardigan['index']=ind
color_musinsa
# Out:
#                                                     img color
# 0     https://image.msscdn.net/images/goods_img/2020...   초록색
# 1     https://image.msscdn.net/images/goods_img/2020...   초록색
# 2     https://image.msscdn.net/images/goods_img/2019...   초록색
# 3     https://image.msscdn.net/images/goods_img/2020...   초록색
# 4     https://image.msscdn.net/images/goods_img/2020...   초록색
# ...                                                 ...   ...
# 8995   https://image.msscdn.net/images/no_image_125.png   보라색
# 8996   https://image.msscdn.net/images/no_image_125.png   보라색
# 8997   https://image.msscdn.net/images/no_image_125.png   보라색
# 8998   https://image.msscdn.net/images/no_image_125.png   보라색
# 8999   https://image.msscdn.net/images/no_image_125.png   보라색
#
# [9000 rows x 2 columns]

# %%
idx=[]
for i in range(26609,35609):
    idx.append(i)
len(idx)
# Out:
# 9000

# %%
color_musinsa['index']=idx
# color_musinsa
color_musinsa=color_musinsa.drop('img',axis=1)
# color_musinsa
color_musinsa=color_musinsa[['index','color']]
color_musinsa
# Out:
#       index color
# 0     26609   초록색
# 1     26610   초록색
# 2     26611   초록색
# 3     26612   초록색
# 4     26613   초록색
# ...     ...   ...
# 8995  35604   보라색
# 8996  35605   보라색
# 8997  35606   보라색
# 8998  35607   보라색
# 8999  35608   보라색
#
# [9000 rows x 2 columns]

# %%
color_musinsa.to_csv('c:/Temp/크롤링/musinsa/color3.csv',encoding='utf-8-sig',index=False)

# %%
from tqdm import tqdm
from urllib.request import urlopen
n=26609
for img_src in tqdm(musinsa_list):
    if img_src == '':
        continue
    else:
        with urlopen(img_src) as f:
            # img라는 폴더 안에 programmer(n).jpg 파일을 저장한다.
            # 텍스트 파일이 아니기 때문에 w(write)만 쓰면 안되고 binary 모드를 추가시켜야 한다.
            with open('c:/Temp/크롤링/musinsa/' + str(n) + '.jpg', "wb") as h:
                # f를 읽고 img에 저장한다.
                img = f.read()
                # h에 위 내용을 쓴다.
                h.write(img)
        # 계속 programmer 1에 덮어쓰지 않도록 1을 증가시켜 준다
        n += 1 
#35608
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 9000/9000 [29:42<00:00,  5.05it/s]

# %%
musinsa_list[-1]
# Out:
# 'https://image.msscdn.net/images/no_image_125.png'
