# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import re
import numpy as np
from bs4 import BeautifulSoup as bs
import pickle
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
browser = webdriver.Chrome('C:/Temp/chromedriver')

# %% [markdown]
# ### 롱/미디 데님

# %%
n=1
img_link=[]
like_list=[]

#검정(164개)
while True:
    browser.get('https://www.ssfshop.com/Long-Midi/list?dspCtgryNo=SFMA41A04A07A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=5%2C4%2C3&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1



#회색(11개)-회색/짙은회색/밝은회색
n=1
while True:
    browser.get('https://www.ssfshop.com/Long-Midi/list?dspCtgryNo=SFMA41A04A07A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=2&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
    
# #노란색(44개)-노란색/레몬색/겨자색
# n=1
# while True:
#     browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=E%2CG%2CF&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
#     time.sleep(3)
    
#     # 사진 링크
#     img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
#     if len(img_tag) == 0:
#         break
#     for x in img_tag:
#         img_url= x.get_attribute('src')
#         img_link.append(img_url)

        
#     # 좋아요
#     like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
#     for x in like:
#         like_list.append(x.text)
          
#     # 
#     n+=1

    
#흰색(98개)-흰색/아이보리
n=1
while True:
    browser.get('https://www.ssfshop.com/Long-Midi/list?dspCtgryNo=SFMA41A04A07A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=1%2C0&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1    

    
    
# #초록색(178개)-카키/녹색/연두색/올리브/애플그린
# n=1
# while True:
#     browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=H%2CM%2CJ%2CL%2CK&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
#     time.sleep(3)
    
#     # 사진 링크
#     img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
#     if len(img_tag) == 0:
#         break
#     for x in img_tag:
#         img_url= x.get_attribute('src')
#         img_link.append(img_url)

        
#     # 좋아요
#     like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
#     for x in like:
#         like_list.append(x.text)
          
#     # 
#     n+=1
    
    
    
#파란색(497개)-하늘색/파란색/로열블루/남색
n=1
while True:
    browser.get('https://www.ssfshop.com/Long-Midi/list?dspCtgryNo=SFMA41A04A07A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=P%2CR%2CQ%2CN&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    

     
#보라색(29개)-와인/라벤다/연보라/보라/자주
# n=1
# while True:
#     browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=Z%2CU%2CS%2CT%2CV&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
#     time.sleep(3)
    
#     # 사진 링크
#     img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
#     if len(img_tag) == 0:
#         break
#     for x in img_tag:
#         img_url= x.get_attribute('src')
#         img_link.append(img_url)

        
#     # 좋아요
#     like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
#     for x in like:
#         like_list.append(x.text)
          
#     # 
#     n+=1
    
    
#빨간색(27개)-빨간색
# n=1
# while True:
#     browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=6&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
#     time.sleep(3)
    
#     # 사진 링크
#     img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
#     if len(img_tag) == 0:
#         break
#     for x in img_tag:
#         img_url= x.get_attribute('src')
#         img_link.append(img_url)

        
#     # 좋아요
#     like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
#     for x in like:
#         like_list.append(x.text)
          
#     # 
#     n+=1

    
#분홍색(52개)-연분홍/분홍/코랄/진분홍
# n=1
# while True:
#     browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=X%2CY%2C7%2CW&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
#     time.sleep(3)
    
#     # 사진 링크
#     img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
#     if len(img_tag) == 0:
#         break
#     for x in img_tag:
#         img_url= x.get_attribute('src')
#         img_link.append(img_url)

        
#     # 좋아요
#     like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
#     for x in like:
#         like_list.append(x.text)
          
#     # 
#     n+=1

    
#갈색(15개)-진한갈색/갈색/황토색
n=1
while True:
    browser.get('https://www.ssfshop.com/Long-Midi/list?dspCtgryNo=SFMA41A04A07A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=A%2CB%2CD&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
print(len(img_link))
print(len(like_list))

#https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage=2&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=3%2C2%2C4&materNM=&cateViewOn=&cateNo=&fitPsbYn=N
# Out:
# 785
# 785

# %% [markdown]
# ## 쇼트 데님

# %%
n=1
img_link=[]
like_list=[]

#검정(16개)
while True:
    browser.get('https://www.ssfshop.com/Shorts/list?dspCtgryNo=SFMA41A04A07A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=5%2C4%2C3&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1



#회색(11개)-회색/짙은회색/밝은회색
# n=1
# while True:
#     browser.get('https://www.ssfshop.com/Long-Midi/list?dspCtgryNo=SFMA41A04A07A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=2&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
#     time.sleep(3)
    
#     # 사진 링크
#     img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
#     if len(img_tag) == 0:
#         break
#     for x in img_tag:
#         img_url= x.get_attribute('src')
#         img_link.append(img_url)

        
#     # 좋아요
#     like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
#     for x in like:
#         like_list.append(x.text)
          
#     # 
#     n+=1

    
    
# #노란색(44개)-노란색/레몬색/겨자색
# n=1
# while True:
#     browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=E%2CG%2CF&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
#     time.sleep(3)
    
#     # 사진 링크
#     img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
#     if len(img_tag) == 0:
#         break
#     for x in img_tag:
#         img_url= x.get_attribute('src')
#         img_link.append(img_url)

        
#     # 좋아요
#     like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
#     for x in like:
#         like_list.append(x.text)
          
#     # 
#     n+=1

    
#흰색(19개)-흰색/아이보리
n=1
while True:
    browser.get('https://www.ssfshop.com/Shorts/list?dspCtgryNo=SFMA41A04A07A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=1%2C0&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1    

    
    
# #초록색(178개)-카키/녹색/연두색/올리브/애플그린
# n=1
# while True:
#     browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=H%2CM%2CJ%2CL%2CK&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
#     time.sleep(3)
    
#     # 사진 링크
#     img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
#     if len(img_tag) == 0:
#         break
#     for x in img_tag:
#         img_url= x.get_attribute('src')
#         img_link.append(img_url)

        
#     # 좋아요
#     like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
#     for x in like:
#         like_list.append(x.text)
          
#     # 
#     n+=1
    
    
    
#파란색(41개)-하늘색/파란색/로열블루/남색
n=1
while True:
    browser.get('https://www.ssfshop.com/Shorts/list?dspCtgryNo=SFMA41A04A07A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=P%2CQ%2CN&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    

     
#보라색(29개)-와인/라벤다/연보라/보라/자주
# n=1
# while True:
#     browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=Z%2CU%2CS%2CT%2CV&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
#     time.sleep(3)
    
#     # 사진 링크
#     img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
#     if len(img_tag) == 0:
#         break
#     for x in img_tag:
#         img_url= x.get_attribute('src')
#         img_link.append(img_url)

        
#     # 좋아요
#     like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
#     for x in like:
#         like_list.append(x.text)
          
#     # 
#     n+=1
    
    
#빨간색(27개)-빨간색
# n=1
# while True:
#     browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=6&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
#     time.sleep(3)
    
#     # 사진 링크
#     img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
#     if len(img_tag) == 0:
#         break
#     for x in img_tag:
#         img_url= x.get_attribute('src')
#         img_link.append(img_url)

        
#     # 좋아요
#     like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
#     for x in like:
#         like_list.append(x.text)
          
#     # 
#     n+=1

    
#분홍색(52개)-연분홍/분홍/코랄/진분홍
# n=1
# while True:
#     browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=X%2CY%2C7%2CW&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
#     time.sleep(3)
    
#     # 사진 링크
#     img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
#     if len(img_tag) == 0:
#         break
#     for x in img_tag:
#         img_url= x.get_attribute('src')
#         img_link.append(img_url)

        
#     # 좋아요
#     like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
#     for x in like:
#         like_list.append(x.text)
          
#     # 
#     n+=1

    
#갈색(2개)-진한갈색/갈색/황토색
n=1
while True:
    browser.get('https://www.ssfshop.com/Shorts/list?dspCtgryNo=SFMA41A04A07A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=A&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
print(len(img_link))
print(len(like_list))

#https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage=2&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=3%2C2%2C4&materNM=&cateViewOn=&cateNo=&fitPsbYn=N
# Out:
# 78
# 78

# %% [markdown]
# ## 롱/미디 포멀

# %%
n=1
img_link=[]
like_list=[]

#검정(333개)
while True:
    browser.get('https://www.ssfshop.com/Long-Midi/list?dspCtgryNo=SFMA41A04A02A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=5&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1



#회색(170개)-회색/짙은회색/밝은회색
n=1
while True:
    browser.get('https://www.ssfshop.com/Long-Midi/list?dspCtgryNo=SFMA41A04A02A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=4%2C3%2C2&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
    
# #노란색(44개)-노란색/레몬색/겨자색
# n=1
# while True:
#     browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=E%2CG%2CF&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
#     time.sleep(3)
    
#     # 사진 링크
#     img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
#     if len(img_tag) == 0:
#         break
#     for x in img_tag:
#         img_url= x.get_attribute('src')
#         img_link.append(img_url)

        
#     # 좋아요
#     like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
#     for x in like:
#         like_list.append(x.text)
          
#     # 
#     n+=1

    
#흰색(121개)-흰색/아이보리
n=1
while True:
    browser.get('https://www.ssfshop.com/Long-Midi/list?dspCtgryNo=SFMA41A04A02A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=0%2C1&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1    

    
    
# #초록색(178개)-카키/녹색/연두색/올리브/애플그린
# n=1
# while True:
#     browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=H%2CM%2CJ%2CL%2CK&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
#     time.sleep(3)
    
#     # 사진 링크
#     img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
#     if len(img_tag) == 0:
#         break
#     for x in img_tag:
#         img_url= x.get_attribute('src')
#         img_link.append(img_url)

        
#     # 좋아요
#     like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
#     for x in like:
#         like_list.append(x.text)
          
#     # 
#     n+=1
    
    
    
#파란색(153개)-하늘색/파란색/로열블루/남색
n=1
while True:
    browser.get('https://www.ssfshop.com/Long-Midi/list?dspCtgryNo=SFMA41A04A02A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=R%2CP%2CQ&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    

     
#보라색(10개)-와인/라벤다/연보라/보라/자주
n=1
while True:
    browser.get('https://www.ssfshop.com/Long-Midi/list?dspCtgryNo=SFMA41A04A02A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=T%2CV%2CU%2CS&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
    
#빨간색(27개)-빨간색
# n=1
# while True:
#     browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=6&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
#     time.sleep(3)
    
#     # 사진 링크
#     img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
#     if len(img_tag) == 0:
#         break
#     for x in img_tag:
#         img_url= x.get_attribute('src')
#         img_link.append(img_url)

        
#     # 좋아요
#     like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
#     for x in like:
#         like_list.append(x.text)
          
#     # 
#     n+=1

    
#분홍색(52개)-연분홍/분홍/코랄/진분홍
# n=1
# while True:
#     browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=X%2CY%2C7%2CW&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
#     time.sleep(3)
    
#     # 사진 링크
#     img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
#     if len(img_tag) == 0:
#         break
#     for x in img_tag:
#         img_url= x.get_attribute('src')
#         img_link.append(img_url)

        
#     # 좋아요
#     like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
#     for x in like:
#         like_list.append(x.text)
          
#     # 
#     n+=1

    
#갈색(102개)-진한갈색/갈색/황토색
n=1
while True:
    browser.get('https://www.ssfshop.com/Long-Midi/list?dspCtgryNo=SFMA41A04A02A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=D%2CB&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
print(len(img_link))
print(len(like_list))

#https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage=2&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=3%2C2%2C4&materNM=&cateViewOn=&cateNo=&fitPsbYn=N
# Out:
# 889
# 889

# %% [markdown]
# ## 쇼트 포멀

# %%
n=1
img_link=[]
like_list=[]

#검정(25개)
while True:
    browser.get('https://www.ssfshop.com/Shorts/list?dspCtgryNo=SFMA41A04A02A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=5&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1



#회색(9개)-회색/짙은회색/밝은회색
n=1
while True:
    browser.get('https://www.ssfshop.com/Shorts/list?dspCtgryNo=SFMA41A04A02A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=4%2C2%2C3&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
    
# #노란색(44개)-노란색/레몬색/겨자색
# n=1
# while True:
#     browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=E%2CG%2CF&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
#     time.sleep(3)
    
#     # 사진 링크
#     img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
#     if len(img_tag) == 0:
#         break
#     for x in img_tag:
#         img_url= x.get_attribute('src')
#         img_link.append(img_url)

        
#     # 좋아요
#     like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
#     for x in like:
#         like_list.append(x.text)
          
#     # 
#     n+=1

    
#흰색(41개)-흰색/아이보리
n=1
while True:
    browser.get('https://www.ssfshop.com/Shorts/list?dspCtgryNo=SFMA41A04A02A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=A%2C0%2C1&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1    

    
    
# #초록색(178개)-카키/녹색/연두색/올리브/애플그린
# n=1
# while True:
#     browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=H%2CM%2CJ%2CL%2CK&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
#     time.sleep(3)
    
#     # 사진 링크
#     img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
#     if len(img_tag) == 0:
#         break
#     for x in img_tag:
#         img_url= x.get_attribute('src')
#         img_link.append(img_url)

        
#     # 좋아요
#     like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
#     for x in like:
#         like_list.append(x.text)
          
#     # 
#     n+=1
    
    
    
#파란색(153개)-하늘색/파란색/로열블루/남색
# n=1
# while True:
#     browser.get('https://www.ssfshop.com/Long-Midi/list?dspCtgryNo=SFMA41A04A02A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=R%2CP%2CQ&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
#     time.sleep(3)
    
#     # 사진 링크
#     img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
#     if len(img_tag) == 0:
#         break
#     for x in img_tag:
#         img_url= x.get_attribute('src')
#         img_link.append(img_url)

        
#     # 좋아요
#     like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
#     for x in like:
#         like_list.append(x.text)
          
#     # 
#     n+=1
    

     
#보라색(10개)-와인/라벤다/연보라/보라/자주
# n=1
# while True:
#     browser.get('https://www.ssfshop.com/Long-Midi/list?dspCtgryNo=SFMA41A04A02A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=T%2CV%2CU%2CS&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
#     time.sleep(3)
    
#     # 사진 링크
#     img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
#     if len(img_tag) == 0:
#         break
#     for x in img_tag:
#         img_url= x.get_attribute('src')
#         img_link.append(img_url)

        
#     # 좋아요
#     like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
#     for x in like:
#         like_list.append(x.text)
          
#     # 
#     n+=1
    
    
#빨간색(27개)-빨간색
# n=1
# while True:
#     browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=6&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
#     time.sleep(3)
    
#     # 사진 링크
#     img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
#     if len(img_tag) == 0:
#         break
#     for x in img_tag:
#         img_url= x.get_attribute('src')
#         img_link.append(img_url)

        
#     # 좋아요
#     like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
#     for x in like:
#         like_list.append(x.text)
          
#     # 
#     n+=1

    
#분홍색(52개)-연분홍/분홍/코랄/진분홍
# n=1
# while True:
#     browser.get('https://www.ssfshop.com/Jackets/list?dspCtgryNo=SFMA41A21A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=X%2CY%2C7%2CW&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
#     time.sleep(3)
    
#     # 사진 링크
#     img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
#     if len(img_tag) == 0:
#         break
#     for x in img_tag:
#         img_url= x.get_attribute('src')
#         img_link.append(img_url)

        
#     # 좋아요
#     like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
#     for x in like:
#         like_list.append(x.text)
          
#     # 
#     n+=1

    
#갈색(3개)-진한갈색/갈색/황토색
n=1
while True:
    browser.get('https://www.ssfshop.com/Shorts/list?dspCtgryNo=SFMA41A04A02A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=B%2CD&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
print(len(img_link))
print(len(like_list))

#https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage=2&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=3%2C2%2C4&materNM=&cateViewOn=&cateNo=&fitPsbYn=N
# Out:
# 78
# 78

# %% [markdown]
# ## 롱/미디 스커트

# %%
n=1
img_link=[]
like_list=[]

#검정(482개)
while True:
    browser.get('https://www.ssfshop.com/Long-Midi/list?dspCtgryNo=SFMA41A05A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=5&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1



#회색(171개)-회색/짙은회색/밝은회색
n=1
while True:
    browser.get('https://www.ssfshop.com/Long-Midi/list?dspCtgryNo=SFMA41A05A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=4%2C3%2C2&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
    
# #노란색(55개)-노란색/레몬색/겨자색
n=1
while True:
    browser.get('https://www.ssfshop.com/Long-Midi/list?dspCtgryNo=SFMA41A05A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=E%2CF%2CG&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
#흰색(244개)-흰색/아이보리
n=1
while True:
    browser.get('https://www.ssfshop.com/Long-Midi/list?dspCtgryNo=SFMA41A05A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=0%2C1&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1    

    
    
# #초록색(186개)-카키/녹색/연두색/올리브/애플그린
n=1
while True:
    browser.get('https://www.ssfshop.com/Long-Midi/list?dspCtgryNo=SFMA41A05A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=H%2CM%2CL%2CJ%2CK&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
    
    
#파란색(348개)-하늘색/파란색/로열블루/남색
n=1
while True:
    browser.get('https://www.ssfshop.com/Long-Midi/list?dspCtgryNo=SFMA41A05A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=R%2CQ%2CP%2CN&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    

     
#보라색(30개)-와인/라벤다/연보라/보라/자주
n=1
while True:
    browser.get('https://www.ssfshop.com/Long-Midi/list?dspCtgryNo=SFMA41A05A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=Z%2CU%2CV%2CS&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
    
#빨간색(23개)-빨간색
n=1
while True:
    browser.get('https://www.ssfshop.com/Long-Midi/list?dspCtgryNo=SFMA41A05A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=6&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
#분홍색(55개)-연분홍/분홍/코랄/진분홍
n=1
while True:
    browser.get('https://www.ssfshop.com/Long-Midi/list?dspCtgryNo=SFMA41A05A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=X%2CY%2C7%2CW&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
#갈색(198개)-진한갈색/갈색/황토색
n=1
while True:
    browser.get('https://www.ssfshop.com/Long-Midi/list?dspCtgryNo=SFMA41A05A01&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=D%2CB%2CC&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
print(len(img_link))
print(len(like_list))

#https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage=2&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=3%2C2%2C4&materNM=&cateViewOn=&cateNo=&fitPsbYn=N
# Out:
# 1792
# 1792

# %% [markdown]
# ## 쇼트 스커트

# %%
n=1
img_link=[]
like_list=[]

#검정(115개)
while True:
    browser.get('https://www.ssfshop.com/Mini/list?dspCtgryNo=SFMA41A05A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=5&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1



#회색(35개)-회색/짙은회색/밝은회색
n=1
while True:
    browser.get('https://www.ssfshop.com/Mini/list?dspCtgryNo=SFMA41A05A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=4%2C3%2C2&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
    
# #노란색(17개)-노란색/레몬색/겨자색
n=1
while True:
    browser.get('https://www.ssfshop.com/Mini/list?dspCtgryNo=SFMA41A05A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=E%2CF%2CG&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
#흰색(24개)-흰색/아이보리
n=1
while True:
    browser.get('https://www.ssfshop.com/Mini/list?dspCtgryNo=SFMA41A05A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=1&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1    

    
    
# #초록색(26개)-카키/녹색/연두색/올리브/애플그린
n=1
while True:
    browser.get('https://www.ssfshop.com/Mini/list?dspCtgryNo=SFMA41A05A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=M%2CH%2CJ%2CK%2CL&materNM=&cateViewOn=&cateNo=&fitPsbYn=N')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
    
    
#파란색(43개)-하늘색/파란색/로열블루/남색
n=1
while True:
    browser.get('https://www.ssfshop.com/Mini/list?dspCtgryNo=SFMA41A05A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=Q%2CP%2CN&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    

     
#보라색(10개)-와인/라벤다/연보라/보라/자주
n=1
while True:
    browser.get('https://www.ssfshop.com/Mini/list?dspCtgryNo=SFMA41A05A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=U%2CV%2CS%2CT&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
    
#빨간색(15개)-빨간색
n=1
while True:
    browser.get('https://www.ssfshop.com/Mini/list?dspCtgryNo=SFMA41A05A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=6&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
#분홍색(25개)-연분홍/분홍/코랄/진분홍
n=1
while True:
    browser.get('https://www.ssfshop.com/Mini/list?dspCtgryNo=SFMA41A05A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=X%2CY%2C7&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1

    
#갈색(39개)-진한갈색/갈색/황토색
n=1
while True:
    browser.get('https://www.ssfshop.com/Mini/list?dspCtgryNo=SFMA41A05A02&brandShopNo=&brndShopId=&currentPage='+str(n)+'&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=D%2CB%2CC&materNM=&cateViewOn=&cateNo=&fitPsbYn=')
    time.sleep(3)
    
    # 사진 링크
    img_tag=browser.find_elements_by_css_selector('#dspGood > li > a > span > img')
    if len(img_tag) == 0:
        break
    for x in img_tag:
        img_url= x.get_attribute('src')
        img_link.append(img_url)

        
    # 좋아요
    like=browser.find_elements_by_css_selector('#dspGood > li > a > div.info > span.score > span.heart > em')
    for x in like:
        like_list.append(x.text)
          
    # 
    n+=1
    
print(len(img_link))
print(len(like_list))

#https://www.ssfshop.com/Cardigans/list?dspCtgryNo=SFMA41A03A02&brandShopNo=&brndShopId=&currentPage=2&sortColumn=SALE_QTY_SEQ&etcCtgryNo=&leftBrandNM=&serviceType=DSP&smtFlterVal=&price=&benefit=&delivery=&lineId=&ctgrySectCd=GNRL_CTGRY&brndId=&sizeNM=&colorCd=3%2C2%2C4&materNM=&cateViewOn=&cateNo=&fitPsbYn=N
# Out:
# 349
# 349

# %%
######롱/미디 데님
black=['검정색' for i in range(164)]
gray=['회색' for i in range(11)]
# yellow=['노란색' for i in range(12)]
white=['흰색' for i in range(98)]
# green=['초록색' for i in range(122)]
blue=['파란색' for i in range(497)]
# purple=['보라색' for i in range(19)]
# red=['빨간색' for i in range(17)]
# pink=['분홍색' for i in range(32)]
brown=['갈색' for i in range(15)]

color = black+gray+white+blue+brown
len(color)
# Out:
# 785

# %%
######쇼트 데님
black=['검정색' for i in range(16)]
# gray=['회색' for i in range(11)]
# yellow=['노란색' for i in range(12)]
white=['흰색' for i in range(19)]
# green=['초록색' for i in range(122)]
blue=['파란색' for i in range(41)]
# purple=['보라색' for i in range(19)]
# red=['빨간색' for i in range(17)]
# pink=['분홍색' for i in range(32)]
brown=['갈색' for i in range(2)]

color = black+white+blue+brown
len(color)
# Out:
# 78

# %%
######롱/미디 포멀
black=['검정색' for i in range(333)]
gray=['회색' for i in range(170)]
# yellow=['노란색' for i in range(12)]
white=['흰색' for i in range(121)]
# green=['초록색' for i in range(122)]
blue=['파란색' for i in range(153)]
purple=['보라색' for i in range(10)]
# red=['빨간색' for i in range(17)]
# pink=['분홍색' for i in range(32)]
brown=['갈색' for i in range(102)]

color = black+gray+white+blue+purple+brown
len(color)
# Out:
# 889

# %%
######쇼트 포멀
black=['검정색' for i in range(25)]
gray=['회색' for i in range(9)]
# yellow=['노란색' for i in range(12)]
white=['흰색' for i in range(41)]
# green=['초록색' for i in range(122)]
# blue=['파란색' for i in range(153)]
# purple=['보라색' for i in range(10)]
# red=['빨간색' for i in range(17)]
# pink=['분홍색' for i in range(32)]
brown=['갈색' for i in range(3)]

color = black+gray+white+brown
len(color)
# Out:
# 78

# %%
######롱/미디 스커트
black=['검정색' for i in range(482)]
gray=['회색' for i in range(171)]
yellow=['노란색' for i in range(55)]
white=['흰색' for i in range(244)]
green=['초록색' for i in range(186)]
blue=['파란색' for i in range(348)]
purple=['보라색' for i in range(30)]
red=['빨간색' for i in range(23)]
pink=['분홍색' for i in range(55)]
brown=['갈색' for i in range(198)]

color = black+gray+yellow+white+green+blue+purple+red+pink+brown
len(color)
# Out:
# 1792

# %%
######쇼트 스커트
black=['검정색' for i in range(115)]
gray=['회색' for i in range(35)]
yellow=['노란색' for i in range(17)]
white=['흰색' for i in range(24)]
green=['초록색' for i in range(26)]
blue=['파란색' for i in range(43)]
purple=['보라색' for i in range(10)]
red=['빨간색' for i in range(15)]
pink=['분홍색' for i in range(25)]
brown=['갈색' for i in range(39)]

color = black+gray+yellow+white+green+blue+purple+red+pink+brown
len(color)
# Out:
# 349

# %%
115 35 17 24 26 43 10 15 25 39

# %% [markdown]
# ## 데이터프레임 만들기

# %%
###########롱/미디 데님
import csv
# color=[]
category=[]
# for x in range(len(like_list)):
#     color.append('회색')
for x in range(len(like_list)):
    category.append('롱&미디 데님')

with open('C:/Temp/크롤링/8seconds/롱&미디 데님/long_midi.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['img','like','color','type'])
    for i in range(len(img_link)):
        writer.writerow((img_link[i],like_list[i],color[i],category[i]))

long_midi=pd.read_csv('C:/Temp/크롤링/8seconds/롱&미디 데님/long_midi.csv')
# ind=list(range(1,142))
# ess_gray_cardigan['index']=ind
long_midi
# Out:
#                                                    img   like color     type
# 0    https://img.ssfshop.com/cmd/LB_500x660/src/htt...  248.0   검정색  롱&미디 데님
# 1    https://img.ssfshop.com/cmd/LB_500x660/src/htt...  184.0   검정색  롱&미디 데님
# 2    https://img.ssfshop.com/cmd/LB_500x660/src/htt...  234.0   검정색  롱&미디 데님
# 3    https://img.ssfshop.com/cmd/LB_500x660/src/htt...  146.0   검정색  롱&미디 데님
# 4    https://img.ssfshop.com/cmd/LB_500x660/src/htt...   37.0   검정색  롱&미디 데님
# ..                                                 ...    ...   ...      ...
# 780  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    1.0    갈색  롱&미디 데님
# 781  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    4.0    갈색  롱&미디 데님
# 782  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    1.0    갈색  롱&미디 데님
# 783  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    NaN    갈색  롱&미디 데님
# 784  https://img.ssfshop.com/cmd/LB_500x660/src/htt...  628.0    갈색  롱&미디 데님
#
# [785 rows x 4 columns]

# %%
###########쇼트 데님
import csv
# color=[]
category=[]
# for x in range(len(like_list)):
#     color.append('회색')
for x in range(len(like_list)):
    category.append('쇼트 데님')

with open('C:/Temp/크롤링/8seconds/쇼트 데님/short.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['img','like','color','type'])
    for i in range(len(img_link)):
        writer.writerow((img_link[i],like_list[i],color[i],category[i]))

short=pd.read_csv('C:/Temp/크롤링/8seconds/쇼트 데님/short.csv')
# ind=list(range(1,142))
# ess_gray_cardigan['index']=ind
short
# Out:
#                                                   img  like color   type
# 0   https://img.ssfshop.com/cmd/LB_500x660/src/htt...  12.0   검정색  쇼트 데님
# 1   https://img.ssfshop.com/cmd/LB_500x660/src/htt...   5.0   검정색  쇼트 데님
# 2   https://img.ssfshop.com/cmd/LB_500x660/src/htt...  33.0   검정색  쇼트 데님
# 3   https://img.ssfshop.com/cmd/LB_500x660/src/htt...   2.0   검정색  쇼트 데님
# 4   https://img.ssfshop.com/cmd/LB_500x660/src/htt...   3.0   검정색  쇼트 데님
# ..                                                ...   ...   ...    ...
# 73  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   NaN   파란색  쇼트 데님
# 74  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   NaN   파란색  쇼트 데님
# 75  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   NaN   파란색  쇼트 데님
# 76  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   5.0    갈색  쇼트 데님
# 77  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   6.0    갈색  쇼트 데님
#
# [78 rows x 4 columns]

# %%
###########롱/미디 포멀
import csv
# color=[]
category=[]
# for x in range(len(like_list)):
#     color.append('회색')
for x in range(len(like_list)):
    category.append('롱&미디 포멀')

with open('C:/Temp/크롤링/8seconds/롱&미디 포멀/long_midi_formal.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['img','like','color','type'])
    for i in range(len(img_link)):
        writer.writerow((img_link[i],like_list[i],color[i],category[i]))

long_midi_formal=pd.read_csv('C:/Temp/크롤링/8seconds/롱&미디 포멀/long_midi_formal.csv')
# ind=list(range(1,142))
# ess_gray_cardigan['index']=ind
long_midi_formal
# Out:
#                                                    img like color     type
# 0    https://img.ssfshop.com/cmd/LB_500x660/src/htt...  321   검정색  롱&미디 포멀
# 1    https://img.ssfshop.com/cmd/LB_500x660/src/htt...  169   검정색  롱&미디 포멀
# 2    https://img.ssfshop.com/cmd/LB_500x660/src/htt...  132   검정색  롱&미디 포멀
# 3    https://img.ssfshop.com/cmd/LB_500x660/src/htt...   94   검정색  롱&미디 포멀
# 4    https://img.ssfshop.com/cmd/LB_500x660/src/htt...   72   검정색  롱&미디 포멀
# ..                                                 ...  ...   ...      ...
# 884  https://img.ssfshop.com/cmd/LB_500x660/src/htt...  NaN    갈색  롱&미디 포멀
# 885  https://img.ssfshop.com/cmd/LB_500x660/src/htt...  634    갈색  롱&미디 포멀
# 886  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    8    갈색  롱&미디 포멀
# 887  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    4    갈색  롱&미디 포멀
# 888  https://img.ssfshop.com/cmd/LB_500x660/src/htt...  NaN    갈색  롱&미디 포멀
#
# [889 rows x 4 columns]

# %%
###########쇼트 포멀
import csv
# color=[]
category=[]
# for x in range(len(like_list)):
#     color.append('회색')
for x in range(len(like_list)):
    category.append('쇼트 포멀')

with open('C:/Temp/크롤링/8seconds/쇼트 포멀/short_formal.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['img','like','color','type'])
    for i in range(len(img_link)):
        writer.writerow((img_link[i],like_list[i],color[i],category[i]))

short_formal=pd.read_csv('C:/Temp/크롤링/8seconds/쇼트 포멀/short_formal.csv')
# ind=list(range(1,142))
# ess_gray_cardigan['index']=ind
short_formal
# Out:
#                                                   img  like color   type
# 0   https://img.ssfshop.com/cmd/LB_500x660/src/htt...   3.0   검정색  쇼트 포멀
# 1   https://img.ssfshop.com/cmd/LB_500x660/src/htt...   7.0   검정색  쇼트 포멀
# 2   https://img.ssfshop.com/cmd/LB_500x660/src/htt...   2.0   검정색  쇼트 포멀
# 3   https://img.ssfshop.com/cmd/LB_500x660/src/htt...   NaN   검정색  쇼트 포멀
# 4   https://img.ssfshop.com/cmd/LB_500x660/src/htt...   1.0   검정색  쇼트 포멀
# ..                                                ...   ...   ...    ...
# 73  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   NaN    흰색  쇼트 포멀
# 74  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   NaN    흰색  쇼트 포멀
# 75  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   1.0    갈색  쇼트 포멀
# 76  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   NaN    갈색  쇼트 포멀
# 77  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   1.0    갈색  쇼트 포멀
#
# [78 rows x 4 columns]

# %%
###########롱/미디 스커트
import csv
# color=[]
category=[]
# for x in range(len(like_list)):
#     color.append('회색')
for x in range(len(like_list)):
    category.append('롱&미디 스커트')

with open('C:/Temp/크롤링/8seconds/롱&미디 스커트/long_midi_skirt.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['img','like','color','type'])
    for i in range(len(img_link)):
        writer.writerow((img_link[i],like_list[i],color[i],category[i]))

long_midi_skirt=pd.read_csv('C:/Temp/크롤링/8seconds/롱&미디 스커트/long_midi_skirt.csv')
# ind=list(range(1,142))
# ess_gray_cardigan['index']=ind
long_midi_skirt
# Out:
#                                                     img   like color      type
# 0     https://img.ssfshop.com/cmd/LB_500x660/src/htt...  121.0   검정색  롱&미디 스커트
# 1     https://img.ssfshop.com/cmd/LB_500x660/src/htt...  122.0   검정색  롱&미디 스커트
# 2     https://img.ssfshop.com/cmd/LB_500x660/src/htt...   63.0   검정색  롱&미디 스커트
# 3     https://img.ssfshop.com/cmd/LB_500x660/src/htt...  457.0   검정색  롱&미디 스커트
# 4     https://img.ssfshop.com/cmd/LB_500x660/src/htt...   99.0   검정색  롱&미디 스커트
# ...                                                 ...    ...   ...       ...
# 1787  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    1.0    갈색  롱&미디 스커트
# 1788  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    4.0    갈색  롱&미디 스커트
# 1789  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    NaN    갈색  롱&미디 스커트
# 1790  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    NaN    갈색  롱&미디 스커트
# 1791  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   11.0    갈색  롱&미디 스커트
#
# [1792 rows x 4 columns]

# %%
###########쇼트 스커트
import csv
# color=[]
category=[]
# for x in range(len(like_list)):
#     color.append('회색')
for x in range(len(like_list)):
    category.append('쇼트 스커트')

with open('C:/Temp/크롤링/8seconds/쇼트 스커트/short_skirt.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['img','like','color','type'])
    for i in range(len(img_link)):
        writer.writerow((img_link[i],like_list[i],color[i],category[i]))

short_skirt=pd.read_csv('C:/Temp/크롤링/8seconds/쇼트 스커트/short_skirt.csv')
# ind=list(range(1,142))
# ess_gray_cardigan['index']=ind
short_skirt
# Out:
#                                                    img   like color    type
# 0    https://img.ssfshop.com/cmd/LB_500x660/src/htt...   99.0   검정색  쇼트 스커트
# 1    https://img.ssfshop.com/cmd/LB_500x660/src/htt...   70.0   검정색  쇼트 스커트
# 2    https://img.ssfshop.com/cmd/LB_500x660/src/htt...   50.0   검정색  쇼트 스커트
# 3    https://img.ssfshop.com/cmd/LB_500x660/src/htt...   59.0   검정색  쇼트 스커트
# 4    https://img.ssfshop.com/cmd/LB_500x660/src/htt...    6.0   검정색  쇼트 스커트
# ..                                                 ...    ...   ...     ...
# 344  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    NaN    갈색  쇼트 스커트
# 345  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    2.0    갈색  쇼트 스커트
# 346  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    NaN    갈색  쇼트 스커트
# 347  https://img.ssfshop.com/cmd/LB_500x660/src/htt...    3.0    갈색  쇼트 스커트
# 348  https://img.ssfshop.com/cmd/LB_500x660/src/htt...  117.0    갈색  쇼트 스커트
#
# [349 rows x 4 columns]

# %%
a = len(long_midi)
b = len(short)
c = len(long_midi_formal)
d = len(short_formal)
e = len(long_midi_skirt)
f = len(short_skirt)
a+b+c+d+e+f
# Out:
# 3971

# %%
pants=pd.concat([long_midi,short,long_midi_formal,short_formal,long_midi_skirt,short_skirt])
len(pants)
# Out:
# 3971

# %%
pants.head()
# Out:
#                                                  img like color     type
# 0  https://img.ssfshop.com/cmd/LB_500x660/src/htt...  248   검정색  롱&미디 데님
# 1  https://img.ssfshop.com/cmd/LB_500x660/src/htt...  184   검정색  롱&미디 데님
# 2  https://img.ssfshop.com/cmd/LB_500x660/src/htt...  234   검정색  롱&미디 데님
# 3  https://img.ssfshop.com/cmd/LB_500x660/src/htt...  146   검정색  롱&미디 데님
# 4  https://img.ssfshop.com/cmd/LB_500x660/src/htt...   37   검정색  롱&미디 데님
